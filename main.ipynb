# %% [markdown]
# # Marseille Food Tour
#
# ![food-tour.png](https://i.postimg.cc/7Lqxx9gT/food-tour.png)
#
# Le projet Marseille Food Tour est conçu pour exploiter les données afin d’optimiser l’expérience touristique gastronomique à Marseille. À cet effet, il intègre un wrapper médiateur qui centralise et standardise l’accès aux différentes sources de données (bases SQL, API externes, etc.), facilitant ainsi leur intégration dans le système global.
#
# Par ailleurs, le projet met en œuvre des vues matérialisées pour pré-calculer et stocker des agrégats de données complexes (Calculs de Distances), permettant une consultation rapide et performante lors des analyses. Ces vues sont automatiquement rafraîchies via des cron jobs, assurant que les données présentées restent toujours à jour et pertinentes.

# %% [markdown]
# ### Le portage de notre projet sur Databricks Community Edition est conçu pour être entièrement scalable et prêt à évoluer.
#
# ### Voici les points clés :
#
#
# Les fichiers CSV sources, représentant des données historiques, sont importés et traités pour constituer nos DataFrames. En parallèle, nous enrichissons ces données en consommant avec soin des APIs pour obtenir des informations météorologiques en temps réel.
#
# Un wrapper médiateur centralise l'accès aux différentes sources de données, facilitant l'intégration de nouvelles sources ou services à mesure que le projet se développe.
# De plus, l'utilisation de vues matérialisées permet de pré-calculer des agrégats pour accélérer les requêtes analytiques, même en cas de volume de données croissant.
#
# Pour garantir que les vues matérialisées et les données météo restent à jour, nous pouvons mettre en place des Job Scheduler de Databricks qui automatisent leur rafraîchissement régulier. Cette solution offre un bon compromis pour garantir la vitesse des requetes et la pertinence des données.
#
# L'architecture actuelle prépare le projet à supporter une extension future, que ce soit par l'ajout de nouvelles sources de données, l'intégration de services complémentaires ou le passage à un environnement de production plus large. Cette approche modulaire ouvre la voie à un développement continu et flexible de notre solution.

# %% [markdown]
# ### Les données viennent de data.gouv.fr

# %% [markdown]
# ### Vous trouverez les Vues Construites un peu plus bas

# %% [markdown]
# ### Le but de ce projet est de permettre des requetes rapides pour trouver des élements de plusieurs tables postgresql les plus proches ( selon la distance géographique )
# ### Vous trouverez quelques exemples concrets d'utilisations que vous pourrez executer à la fin du notebook

# %%
# %pip install SQLAlchemy==2.0.40
# Out:
# Requirement already satisfied: SQLAlchemy==2.0.40 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (2.0.40)
# Requirement already satisfied: greenlet>=1 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from SQLAlchemy==2.0.40) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from SQLAlchemy==2.0.40) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine, types, text
import psycopg2
from psycopg2.extras import execute_values


# ---------------------------
# Environment variables setup
# ---------------------------

# You'll need to set up a database

DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "food_tour"
DB_USER = "postgres"
DB_PASSWORD = "root"

# %%
API_KEY = ""  # Your OpenWeatherMap API key

# %%
# Base abstract class for all wrappers
class BaseWrapper:
    def __init__(self, data_source=None):
        self.data_source = data_source
    def load_data(self, data_source):
        print(f"📄 Lecture du fichier CSV : {data_source}")
        df = pd.read_csv(data_source)
        # raise NotImplementedError("Subclasses should implement load_data method")
        return df
    def preprocess_data(self, df):
        raise NotImplementedError("Subclasses should implement preprocess_data method")
    def run(self):
        df = self.load_data(self.data_source)
        df = self.preprocess_data(df)
        return df

# %%
# Concrete implementation using OpenWeatherMap API
class OpenWeatherMapWrapper(BaseWrapper):
    BASE_URL = "https://api.openweathermap.org/data/2.5/forecast"
    # TABLE_NAME = "meteo_forecast"
    API_KEY = "2ec05eca6b9b8b051818e2aa3aedc23b"  # Your OpenWeatherMap API key
# ---------------------------
    def __init__(self):
        self.api_key = API_KEY
        self.data_source = "Marseille,FR"
        self.column_types = {
            "timestamp": types.TIMESTAMP(timezone=True),
            "temperature": types.NUMERIC(5, 2),
            "humidity": types.INTEGER,
            "wind_speed": types.NUMERIC(5, 2),
            "weather_description": types.TEXT
        }
        # self.table_name = "meteo_forecast"

        
    def load_data(self, location):
        params = {
            "appid": self.api_key,
            "units": "metric"  # Use metric units (temperature in Celsius, wind speed in m/s)
        }
        # Accept location as a city name (e.g., "Marseille,FR") or (lat,lon) tuple.
        if isinstance(location, str):
            params["q"] = location
        elif isinstance(location, tuple) and len(location) == 2:
            params["lat"] = location[0]
            params["lon"] = location[1]
        else:
            raise ValueError("location must be a string (city name) or a (lat, lon) tuple")
        
        response = requests.get(self.BASE_URL, params=params)
        response.raise_for_status()   # Raise an error if the request failed
        return response.json()
    
    def preprocess_data(self, raw_data):
        # Normalize the API's JSON output into a standardized DataFrame.
        # Our goal is to output a DataFrame with the following columns:
        # timestamp, temperature, humidity, wind_speed, weather_description
        records = []
        for entry in raw_data.get("list", []):
            dt = datetime.utcfromtimestamp(entry.get("dt"))
            temp = entry["main"]["temp"]
            humidity = entry["main"]["humidity"]
            wind_speed = entry["wind"]["speed"]
            # There may be several weather entries; we take the first one.
            description = entry["weather"][0]["description"]
            records.append({
                "timestamp": dt,
                "temperature": temp,
                "humidity": humidity,
                "wind_speed": wind_speed,
                "weather_description": description
            })
        return pd.DataFrame(records)
    def run(self):
        data = self.load_data(self.data_source)
        return self.preprocess_data(data)

# %%
class RestaurantDataWrapper(BaseWrapper):

    def __init__(self):
        self.data_source = "restaurants_final.csv"
        self.column_types = {
            "nom": types.Text(),
            "description": types.Text(),
            "adresse": types.Text(),
            "code_postal": types.Integer(),
            "commune": types.Text(),
            "latitude": types.Numeric(9, 6),
            "longitude": types.Numeric(9, 6),
            "periode_ouverte": types.Text(),
            "specialites": types.Text(),
            "review_count": types.Integer(),
            "google_note": types.Numeric(2, 1)
        }

    def preprocess_data(self, df):
        return df

# %%
# ------------------------
# Run block
# ------------------------
restaurant_wrapper = RestaurantDataWrapper()
restaurant_wrapper.run()
# Out:
# 📄 Lecture du fichier CSV : restaurants_final.csv
#                  nom                                        description  \
# 0              Abaco  Cuisine traditionnelle et méridionale raffinée...
# 1    Adonis du Liban  Plongez au coeur de la culture libanaise : nou...
# 2      Tonton Marius  Chez Tonton Marius, c'est un cocon convivial e...
# 3           Al Dente  Nous ouvrons ce restaurant en 1984 et il conna...
# 4    L'Atelier Dkalé  L'Atelier est ouvert du mardi au vendredi pour...
# ..               ...                                                ...
# 614  Shangaï Kitchen  Vous ne vous tromperez pas : c'est bien ici qu...
# 615        Grand Bao  C’est le nouveau restaurant de la Bao Family e...
# 616        Tigermilk  Cuisine sud-américaine servie dans un cadre su...
# 617          MS Club  MS CLUB est bien plus qu'un simple restaurant ...
# 618  Sous le figuier  Situé sur le boulevard Périer, à deux pas de l...
#
#                      adresse  code_postal    commune   latitude  longitude  \
# 0              38 Rue Papety        13007  Marseille  43.290686   5.356852
# 1       10-12 Des Trois Rois        13006  Marseille  43.294179   5.384598
# 2          9 quai du Lazaret        13002  Marseille  43.306758   5.364598
# 3      10 rue Edmond Rostand        13006  Marseille  43.289296   5.379859
# 4    17 Rue Maréchal Fayolle        13004  Marseille  43.300811   5.398588
# ..                       ...          ...        ...        ...        ...
# 614    14 cours Jean Ballard        13001  Marseille  43.293250   5.374266
# 615      3 cours Saint Louis        13001  Marseille  43.296117   5.378259
# 616       23 rue Saint Saëns        13001  Marseille  43.293412   5.373807
# 617          9 Bd Gay Lussac        13011  Marseille  43.334248   5.374000
# 618      97 boulevard Périer        13008  Marseille  43.278564   5.380693
#
#                                        periode_ouverte  \
# 0    Du 02/12 au 31/12, tous les lundis, mardis, me...
# 1    Toute l'année, tous les lundis, mercredis, jeu...
# 2          Toute l'année. Tous les jours de 10h à 20h.
# 3    Toute l'année, tous les jours.\nOuvert midi et...
# 4    Toute l'année, tous les mardis, mercredis, jeu...
# ..                                                 ...
# 614  Toute l'année, tous les mardis, mercredis, jeu...
# 615  Toute l'année, tous les jours de 12h à 23h.\nO...
# 616  Toute l'année, tous les jours de 12h à 23h.\nO...
# 617  Du 01/01/2024 au 31/12/2025, tous les jours de...
# 618  Toute l'année, tous les mardis, mercredis, jeu...
#
#                                            specialites  review_count  \
# 0    Cuisine méditerranéenne, Cuisine traditionnell...          27.0
# 1    Cuisine orientale, Cuisine libanaise, Cuisine ...          28.0
# 2    Cuisine méditerranéenne, Cuisine italienne, Sa...           2.0
# 3           Cuisine méditerranéenne, Cuisine italienne         261.0
# 4                                                  NaN           1.0
# ..                                                 ...           ...
# 614  Cuisine asiatique, Cuisine chinoise, Plats vég...           NaN
# 615                Cuisine asiatique, Cuisine chinoise           NaN
# 616          Cuisine sud-américaine, Plats végétariens           NaN
# 617  Cuisine méditerranéenne, Cuisine traditionnell...           NaN
# 618  Cuisine traditionnelle française, Propose des ...           NaN
#
#      google_note
# 0            4.3
# 1            3.6
# 2            4.5
# 3            3.8
# 4            5.0
# ..           ...
# 614          NaN
# 615          NaN
# 616          NaN
# 617          NaN
# 618          NaN
#
# [619 rows x 11 columns]

# %%
class TransportStopDataInjector(BaseWrapper):
    def __init__(self):
        self.data_source = "cleaned_arrets.csv"
        self.column_types = {
            "id": types.Text(),
            "name": types.Text(),
            "latitude": types.Numeric(9, 6),
            "longitude": types.Numeric(9, 6),
            "description": types.Text(),
            "wheelchair boarding": types.Integer()
        }

    def preprocess_data(self, df):
        """Preprocess the DataFrame: clean column names, split coordinates."""

        # Convert all column names to lowercase (strip whitespace as well)
        df.columns = df.columns.str.strip().str.lower()

        # Manipulate the 'coordinates' column:
        if "coordinates" in df.columns:
            print("🛠️ Splitting 'coordinates' into 'latitude' and 'longitude'...")
            df[['latitude', 'longitude']] = df['coordinates'].str.split(',', expand=True)
            df['latitude'] = df['latitude'].astype(float)
            df['longitude'] = df['longitude'].astype(float)
            df = df.drop(columns=['coordinates'])
        else:
            print("ℹ️ No 'coordinates' column found. Check your CSV format.")
        
        return df

# %%
arrets_wrapper = TransportStopDataInjector()
arrets_wrapper.run()
# Out:
# 📄 Lecture du fichier CSV : cleaned_arrets.csv
# 🛠️ Splitting 'coordinates' into 'latitude' and 'longitude'...
#                 id                     name description  wheelchair boarding  \
# 0     RTM-00001532      3 Frères Barthélemy         NaN                    2
# 1     RTM-00000154  4 Chemins des Aygalades         NaN                    2
# 2     RTM-00000217          5 Avenues Burel         NaN                    2
# 3     RTM-00003085        5 Avenues Fondère         NaN                    2
# 4     RTM-00001955          Aiguier Cantini         NaN                    2
# ...            ...                      ...         ...                  ...
# 2661  RTM-00000152         ZI de la Delorme         NaN                    1
# 2662  RTM-00001938           Zénatti Ecoles         NaN                    2
# 2663  RTM-00001947           Zénatti Ecoles         NaN                    2
# 2664  RTM-00001927          Zénatti Lancier         NaN                    2
# 2665  RTM-00001948          Zénatti Malrieu         NaN                    2
#
#        latitude  longitude
# 0     43.293140   5.385872
# 1     43.346700   5.366183
# 2     43.317198   5.389619
# 3     43.301798   5.399085
# 4     43.257998   5.403374
# ...         ...        ...
# 2661  43.340822   5.365446
# 2662  43.246699   5.385828
# 2663  43.246464   5.386440
# 2664  43.246426   5.383798
# 2665  43.246056   5.389349
#
# [2666 rows x 6 columns]

# %%
class MusicEventDataInjector(BaseWrapper):

    def __init__(self):
        self.data_source = "evenement_musical_cleaned.csv"
        self.column_types = {
            "titre": types.Text(),
            "description": types.Text(),
            "nom_lieu": types.Text(),
            "adresse": types.Text(),
            "ville": types.Text(),
            "code_postal": types.Integer(),
            "latitude": types.Numeric(9, 6),
            "longitude": types.Numeric(9, 6),
            "date_debut": types.DateTime(),
            "date_fin": types.DateTime()
        }
        
    def preprocess_data(self, df):
        
        # Normalize column names: strip, lowercase and replace spaces with underscores
        df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
        print("Detected columns:", df.columns.tolist())

        # Ensure correct numeric types for the relevant columns
        df["code_postal"] = pd.to_numeric(df["code_postal"], errors="coerce").astype("Int64")
        df["longitude"] = pd.to_numeric(df["longitude"], errors="coerce")
        df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
        return df

# %%
music_event_injector = MusicEventDataInjector()
music_event_injector.run()
# Out:
# 📄 Lecture du fichier CSV : evenement_musical_cleaned.csv
# Detected columns: ['titre', 'description', 'nom_lieu', 'adresse', 'ville', 'code_postal', 'latitude', 'longitude', 'date_debut', 'date_fin']
#                                                  titre         description  \
# 0    Concert & repas de soutien: Roms dans la guerr...                 ♫♫♫
# 1                                 DESCARGAS CUBANAS #4                 ♫♫♫
# 2                                      Swinging Papy's              ♫JAZZ♫
# 3             LocoMuerte kami no ikari Rising All Star  ♫TRASH PUNK METAL♫
# 4                               Jam open Mic / Concert                 ♫♫♫
# ..                                                 ...                 ...
# 419                                          LA FOUINE                 ♫♫♫
# 420                                             LOUANE                 ♫♫♫
# 421                                       Ara Malikian                 ♫♫♫
# 422                                          Kim Wilde                 ♫♫♫
# 423                                      Mélanz Nasyon            ♫MALOYA♫
#
#                           nom_lieu                                   adresse  \
# 0    La Dar Centre Social Autogéré        127, rue d'Aubagne 13006 Marseille
# 1                          Club 27           27, rue d'Anvers13004 Marseille
# 2                       L'arlequin            1, rue Missiri 13013 Marseille
# 3                           Makeda          103 rue Ferrari, 13005 Marseille
# 4                 Bar de La Plaine     57 Place Jean Jaurès, 13005 Marseille
# ..                             ...                                       ...
# 419                        le Dôme  48 Avenue de Saint-Just, 13004 Marseille
# 420                        le Dôme  48 Avenue de Saint-Just, 13004 Marseille
# 421                        le Silo       35 quai du Lazaret, 13002 Marseille
# 422                        le Silo       35 quai du Lazaret, 13002 Marseille
# 423                         Makeda          103 rue Ferrari, 13005 Marseille
#
#          ville  code_postal   latitude  longitude                 date_debut  \
# 0    Marseille        13006  43.293333   5.382115  2025-04-10 19:00:00+02:00
# 1    Marseille        13004  43.303056   5.395165  2025-04-10 19:00:00+02:00
# 2    Marseille        13014  43.355711   5.410335  2025-04-10 19:30:00+02:00
# 3    Marseille        13005  43.293709   5.391759  2025-04-10 19:30:00+02:00
# 4    Marseille        13005  43.293987   5.386669  2025-04-10 20:00:00+02:00
# ..         ...          ...        ...        ...                        ...
# 419  Marseille        13013  43.314877   5.404349  2026-01-20 20:00:00+01:00
# 420  Marseille        13013  43.314877   5.404349  2026-01-30 20:00:00+01:00
# 421  Marseille        13002  43.310347   5.367188  2026-03-23 20:00:00+01:00
# 422  Marseille        13002  43.310347   5.367188  2026-04-16 20:30:00+02:00
# 423  Marseille        13005  43.293709   5.391759  2026-11-04 20:00:00+01:00
#
#                       date_fin
# 0    2025-04-10 22:30:00+02:00
# 1    2025-04-10 22:00:00+02:00
# 2    2025-04-10 23:59:00+02:00
# 3    2025-04-10 23:00:00+02:00
# 4    2025-04-11 01:00:00+02:00
# ..                         ...
# 419  2026-01-20 23:00:00+01:00
# 420  2026-01-30 23:00:00+01:00
# 421  2026-03-23 22:00:00+01:00
# 422  2026-04-16 23:30:00+02:00
# 423  2026-11-04 23:00:00+01:00
#
# [424 rows x 10 columns]

# %%
import ast
class TransportLineDataWrapper(BaseWrapper):
    def __init__(self):
        self.data_source = "lignes_transport_with_stop_ids.csv"
        self.column_types = {
            "id": types.Text(),
            "short_name": types.Text(),
            "long_name": types.Text(),
            "route_type": types.Text(),  # 'Bus', 'Tram', etc.
            "color": types.Text()
        }
    def load_data(self, data_source):
        """Read CSV and prepare dataframe."""
        print(f"📄 Reading CSV file: {self.data_source}")
        df = pd.read_csv(self.data_source, sep=";")
        return df
    def preprocess_data(self, df):
        # Normalize column names
        df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
        df = df[['id', 'short_name', 'long_name', 'route_type', 'color']]
        df.columns = ['id', 'short_name', 'long_name', 'route_type', 'color']
        return df

# %%
#test
transport_line_wrapper = TransportLineDataWrapper()
transport_line_wrapper.run()
# Out:
# 📄 Reading CSV file: lignes_transport_with_stop_ids.csv
#           id short_name                                long_name route_type  \
# 0      RTM-9          5                Métro La Rose - La Parade        Bus
# 1     RTM-14          6           Foch 5 Avenues - Bois Lemaître        Bus
# 2     RTM-19         7T       Foch 5 Avenues - Allauch Barbaraou        Bus
# 3     RTM-13          9   Les Caillols Centre Urbain - St Julien        Bus
# 4     AUB-10         10  Gare Aubagne - Font de Mai - La Treille        Bus
# ..       ...        ...                                      ...        ...
# 147  RTM-122       144S                  Métro La Rose - Allauch        Bus
# 148  RTM-121        144                  Métro La Rose - Allauch        Bus
# 149  RTM-107        530    Canebière Bourse - La Savine Les Pins        Bus
# 150  RTM-108        533             Canebière Bourse - Géraniums        Bus
# 151  RTM-110        582        Canebière Bourse - Foch 5 Avenues        Bus
#
#       color
# 0    009FE3
# 1    F39200
# 2    FBBA00
# 3    189B52
# 4    E8378D
# ..      ...
# 147  E73333
# 148  009FE3
# 149  009FE3
# 150  009640
# 151  EA5160
#
# [152 rows x 5 columns]

# %%
import ast
class TransportLineStopsDataWrapper(BaseWrapper):
    def __init__(self):
        self.data_source = "lignes_transport_with_stop_ids.csv"
        self.column_types = {
            "line_id": types.Text(),
            "stop_id": types.Text()
        }
    def load_data(self, data_source):
        """Read CSV and prepare dataframe."""
        print(f"📄 Reading CSV file: {self.data_source}")
        df = pd.read_csv(self.data_source, sep=";")
        df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
        # print("Detected columns:", df.columns.tolist())
        
        return df
    def preprocess_data(self, df):
        # Normalize column names
        df = df[['id', 'short_name', 'long_name', 'route_type', 'color', 'geo_point_2d', 'stop_ids']]
        df.columns = ['id', 'short_name', 'long_name', 'route_type', 'color', 'geo_point_2d', 'stop_ids']
        line_stop_pairs = []

        for _, row in df.iterrows():
            line_id = row['id']
            try:
                stop_ids = ast.literal_eval(row['stop_ids'])  # Parse the string into a Python list
                for stop_id in stop_ids:
                    line_stop_pairs.append({'line_id': line_id, 'stop_id': stop_id})
            except Exception as e:
                print(f"⚠️ Error parsing stop_ids for line {line_id}: {e}")

        df_line_stops = pd.DataFrame(line_stop_pairs)
        return df_line_stops

# %%
line_stops_wrapper = TransportLineStopsDataWrapper()
line_stops_wrapper.run()
# Out:
# 📄 Reading CSV file: lignes_transport_with_stop_ids.csv
#       line_id       stop_id
# 0       RTM-9  RTM-00003930
# 1       RTM-9  RTM-00003931
# 2       RTM-9  RTM-00000738
# 3       RTM-9  RTM-00000731
# 4       RTM-9  RTM-00000677
# ...       ...           ...
# 5481  RTM-110  RTM-00003828
# 5482  RTM-110  RTM-00003828
# 5483  RTM-110  RTM-00002051
# 5484  RTM-110  RTM-00000468
# 5485  RTM-110  RTM-00004401
#
# [5486 rows x 2 columns]

# %%
class BaignadeDataInjector(BaseWrapper):
    def __init__(self):
        self.data_source = "baignades.csv"
        self.column_types = {
            "nom_du_site": types.Text(),
            "categorie": types.Text(),
            "baignade_surveillee": types.Boolean(),
            "adresse": types.Text(),
            "code_postal": types.Integer(),
            "ville": types.Text(),
            "numero_de_telephone": types.Text(),
            "longitude": types.Numeric(9, 6),
            "latitude": types.Numeric(9, 6)
        }

    def preprocess_data(self, df):
        
        df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
        print("Detected columns:", df.columns.tolist())

        # Convert and clean columns
        df["baignade_surveillee"] = df["baignade_surveillee"].str.strip().str.lower().map({
            "oui": True, "non": False, "non concerne": False
        })
        df["code_postal"] = pd.to_numeric(df["code_postal"], errors="coerce").astype("Int64")
        df["longitude"] = pd.to_numeric(df["longitude"], errors="coerce")
        df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
        return df

# %%
baignade_wrapper = BaignadeDataInjector()
baignade_wrapper.run()
# Out:
# 📄 Lecture du fichier CSV : baignades.csv
# Detected columns: ['nom_du_site', 'categorie', 'baignade_surveillee', 'adresse', 'code_postal', 'ville', 'numero_de_telephone', 'longitude', 'latitude']
#                                nom_du_site        categorie  \
# 0              Base nautique de l'Huveaune  Bases nautiques
# 1                  Base Nautique Corbieres  Bases nautiques
# 2            Base Nautique du Roucas Blanc  Bases nautiques
# 3            Base Nautique de Pointe Rouge  Bases nautiques
# 4                             Plage Borely           Plages
# 5                           Plage de David           Plages
# 6                    Plage du Grand Roucas           Plages
# 7                      Plage de l'Huveaune           Plages
# 8                      Plage de Bonneveine           Plages
# 9             Plage de la Vieille Chapelle           Plages
# 10                Plage de la Pointe Rouge           Plages
# 11                          Bain des Dames           Plages
# 12                       Anse des Phoceens           Plages
# 13  Anse des Sablettes (plage du Colombet)           Plages
# 14                  Bonne Brise (Verrerie)           Plages
# 15                              Les Goudes           Plages
# 16                                 Sormiou           Plages
# 17                                 Morgiou           Plages
# 18                                  En Vau           Plages
# 19                                Port Pin           Plages
# 20                       Plage du Prophete           Plages
# 21                      Plage Les Catalans           Plages
# 22               Plage de Corbiere La Lave           Plages
# 23                Plage de Corbiere Fortin           Plages
# 24                   Plage du Petit Roucas           Plages
# 25                       Corbiere Batterie           Plages
# 26                     Frioul Saint Esteve           Plages
#
#     baignade_surveillee                          adresse  code_postal  \
# 0                 False  109 avenue Pierre Mendes France        13008
# 1                 False           250 plage de l'Estaque        13016
# 2                 False     2 promenade Georges Pompidou        13008
# 3                 False          Port de la pointe Rouge        13008
# 4                  True                              NaN        13008
# 5                  True                              NaN        13008
# 6                  True                              NaN        13008
# 7                  True                              NaN        13008
# 8                  True                              NaN        13008
# 9                  True                              NaN        13008
# 10                 True                              NaN        13008
# 11                False                              NaN        13008
# 12                False                              NaN        13008
# 13                False                              NaN        13008
# 14                False                              NaN        13008
# 15                False                    La Marronaise        13008
# 16                 True                              NaN        13009
# 17                False                              NaN        13009
# 18                False                              NaN        13009
# 19                False                              NaN        13009
# 20                 True                              NaN        13007
# 21                 True                              NaN        13007
# 22                 True                              NaN        13016
# 23                 True                              NaN        13016
# 24                 True                              NaN        13008
# 25                 True                              NaN        13016
# 26                 True                              NaN        13007
#
#         ville numero_de_telephone  longitude   latitude
# 0   Marseille      04 91 76 54 42   5.376404  43.261086
# 1   Marseille      04 91 46 19 37   5.293255  43.358719
# 2   Marseille      04 91 29 30 40   5.371334  43.266873
# 3   Marseille      04 91 73 74 23   5.370918  43.244462
# 4   Marseille                 NaN   5.375060  43.255979
# 5   Marseille                 NaN   5.372253  43.261648
# 6   Marseille                 NaN   5.370885  43.263369
# 7   Marseille                 NaN   5.375597  43.258558
# 8   Marseille                 NaN   5.374763  43.253519
# 9   Marseille                 NaN   5.373735  43.249989
# 10  Marseille                 NaN   5.370918  43.244462
# 11  Marseille                 NaN   5.362628  43.241082
# 12  Marseille                 NaN   5.362287  43.239695
# 13  Marseille                 NaN   5.360873  43.237535
# 14  Marseille                 NaN   5.359961  43.236551
# 15  Marseille                 NaN   5.342991  43.214731
# 16  Marseille                 NaN   5.420195  43.210165
# 17  Marseille                 NaN   5.443772  43.212210
# 18  Marseille                 NaN   5.498216  43.201874
# 19  Marseille                 NaN   5.510660  43.203893
# 20  Marseille                 NaN   5.362303  43.273085
# 21  Marseille                 NaN   5.355142  43.290544
# 22  Marseille                 NaN   5.292954  43.358385
# 23  Marseille                 NaN   5.291226  43.357637
# 24  Marseille                 NaN   5.368619  43.263880
# 25  Marseille                 NaN   5.291833  43.358423
# 26  Marseille                 NaN   5.315791  43.284232

# %% [markdown]
# # Views

# %%
sql_vue_mat_baignades_arrets = """ DROP MATERIALIZED VIEW IF EXISTS baignades_nearest_stops CASCADE;

create materialized view if not exists baignades_nearest_stops as
   with ranked_stops as (
      select b.nom_du_site as nom,
                b.categorie,
                b.baignade_surveillee,
                b.adresse,
                b.numero_de_telephone,
             a.id as arret_id,
             a.name as arret_name,
             b.geog as geog_baignade,
             a.geog as geog_arret,
             st_distance(
                b.geog,
                a.geog
             ) as distance,
             row_number()
             over(partition by b.nom_du_site
                  order by b.geog <-> a.geog
             ) as rn
        from baignades b
        join arrets_transport a
      on st_dwithin(
         b.geog,
         a.geog,
         400
      )
   )
   select nom,
          geog_baignade,
            categorie,
            baignade_surveillee,
            adresse,
            numero_de_telephone,
          arret_id,
          arret_name,
          geog_arret,
          distance
     from ranked_stops
    where rn = 1; """

# %%
sql_vue_mat_baignade_meteo = """
DROP MATERIALIZED VIEW IF EXISTS baignades_meteo CASCADE;
create materialized view if not exists baignades_meteo as
   select b.nom_du_site,
          b.categorie,
          b.baignade_surveillee,
          b.adresse,
          b.numero_de_telephone,
          b.geog as geog_baignade,
          m.timestamp as forecast_time,
          m.temperature as temperature,
          m.humidity as humidite,
          m.wind_speed as vitesse_vent,
          m.weather_description as description_meteo
     from baignades b
    cross join meteo_forecast m
    order by 
             m.timestamp, b.nom_du_site;"""

# %%
sql_vue_mat_baignade_meilleurs_conditions = """
DROP MATERIALIZED VIEW IF EXISTS baignades_best_conditions CASCADE;
CREATE MATERIALIZED VIEW IF NOT EXISTS baignades_best_conditions AS
SELECT nom_du_site, 
          b.categorie,
          b.baignade_surveillee,
          b.adresse,
          b.numero_de_telephone,
          b.geog_baignade,
         forecast_time::date AS date, temperature, humidite, vitesse_vent, description_meteo
FROM baignades_meteo b
WHERE temperature >= 25 AND vitesse_vent <= 20
ORDER BY temperature DESC;
"""

# %%
sql_vue_mat_baignade_temperature_moy = """
DROP MATERIALIZED VIEW IF EXISTS avg_temp_per_baignade CASCADE;
CREATE MATERIALIZED VIEW IF NOT EXISTS avg_temp_per_baignade AS
SELECT
  nom_du_site,
  geog_baignade,
  forecast_time::date AS date,
  AVG(temperature) AS avg_temp
FROM baignades_meteo
GROUP BY nom_du_site, forecast_time::date, geog_baignade
ORDER BY date, avg_temp DESC;
"""

# %%
sql_vue_mat_baignade_arrets_temp = """
DROP MATERIALIZED VIEW IF EXISTS baignades_with_nearest_stop_and_temp CASCADE;
CREATE MATERIALIZED VIEW IF NOT EXISTS baignades_with_nearest_stop_and_temp AS
SELECT bns.nom,
    bns.categorie,
    bns.geog_baignade,
          bns.baignade_surveillee,
        bns.adresse,
        bns.numero_de_telephone,
            bns.arret_name,
          bns.geog_arret,
          bns.distance,
    atb.avg_temp
FROM baignades_nearest_stops bns
JOIN avg_temp_per_baignade atb ON bns.nom = atb.nom_du_site;
"""

# %%
sql_vue_mat_events_arrets ="""drop materialized view if exists evenements_arrets CASCADE;
create MATERIALIZED view if not exists evenements_arrets as
   with ranked_stops as (
      select e.titre as evenement,
                e.description as evenement_description,
                e.nom_lieu as evenement_lieu,
                e.date_debut as debut_evenement,
                e.date_fin as fin_evenement,
             a.id as arret_id,
             a.name as arret_name,
             e.geog as geog_evenement,
             a.geog as geog_arret,
             st_distance(
                e.geog,
                a.geog
             ) as distance,
             row_number()
             over(partition by e.titre
                  order by e.geog <-> a.geog
             ) as rn
        from evenements_musicaux e
        join arrets_transport a
      on st_dwithin(
         e.geog,
         a.geog,
         400
      )
   )
   select evenement,
            evenement_description,
            evenement_lieu,
            debut_evenement,
            fin_evenement,
          arret_id,
          arret_name,
          geog_evenement,
          geog_arret,
          distance
     from ranked_stops
    where rn <= 3;"""

# %%
sql_vue_mat_nb_evenement_arret = """
DROP MATERIALIZED VIEW IF EXISTS nb_evenements_par_arret CASCADE;
CREATE MATERIALIZED VIEW IF NOT EXISTS nb_evenements_par_arret AS
SELECT arret_name, COUNT(*) AS nb_evenements
FROM evenements_arrets
GROUP BY arret_name
ORDER BY nb_evenements DESC;
"""

# %%
sql_vue_mat_restos_arrets = """DROP MATERIALIZED VIEW IF EXISTS restaurant_nearest_stops CASCADE;

CREATE MATERIALIZED VIEW IF NOT EXISTS restaurant_nearest_stops AS
WITH ranked_stops AS (
    SELECT 
        r.nom AS restaurant_name,
        r.description AS restaurant_description,
        r.specialites,
        r.periode_ouverte,
        r.google_note AS note,
        r.review_count AS review_count,
        r.geog AS geog_restaurant,
        a.id AS arret_id,
        a.name AS arret_name,
        a.geog AS geog_arret,
        ST_Distance(r.geog, a.geog) AS distance,
        ROW_NUMBER() OVER (
            PARTITION BY r.nom, a.name
            ORDER BY r.geog <-> a.geog
        ) AS rn
    FROM restaurants r
    JOIN arrets_transport a
        ON ST_DWithin(r.geog, a.geog, 400)  -- within 400m
)
SELECT 
    restaurant_name,
    restaurant_description,
    specialites,
    periode_ouverte,
    note,
    review_count,
    geog_restaurant,
    arret_id,
    arret_name,
    geog_arret,
    distance,
    rn AS stop_rank
FROM ranked_stops
WHERE rn <= 3
ORDER BY restaurant_name, stop_rank;
"""

# %%
sql_mat_event_bon_resto_arret = """DROP MATERIALIZED VIEW IF EXISTS mini_itineraire_event_good_restaurant_arret CASCADE;

CREATE MATERIALIZED VIEW IF NOT EXISTS mini_itineraire_event_good_restaurant_arret AS
WITH nearest_restaurants AS (
    SELECT 
        e.titre AS evenement,
        e.description AS evenement_description,
        e.adresse AS evenement_adresse,
        e.date_debut,
        e.date_fin,
        r.nom AS restaurant_name,
        r.description AS restaurant_description,
        r.specialites,
        r.periode_ouverte,
        r.google_note AS note,
        r.review_count,
        r.geog AS geog_restaurant,
        ST_Distance(e.geog, r.geog) AS distance_event_restaurant,
        e.geog AS geog_evenement,
        ROW_NUMBER() OVER (PARTITION BY e.titre ORDER BY e.geog <-> r.geog) AS rn_restaurant
    FROM evenements_musicaux e
    JOIN restaurants r
      ON ST_DWithin(e.geog, r.geog, 200)
     AND r.google_note >= 3
     AND r.review_count >= 3
),
event_to_restaurant AS (
    SELECT *
    FROM nearest_restaurants
    WHERE rn_restaurant <= 5
),
nearest_stops AS (
    SELECT 
        er.evenement,
        er.evenement_description,
        er.evenement_adresse,
        er.date_debut,
        er.date_fin,
        er.restaurant_name,
        er.restaurant_description,
        er.specialites,
        er.periode_ouverte,
        er.note,
        er.review_count,
        er.geog_evenement,
        er.geog_restaurant,
        er.distance_event_restaurant,
        a.id AS arret_id,
        a.name AS arret_name,
        a.geog AS geog_arret,
        ST_Distance(er.geog_restaurant, a.geog) AS distance_restaurant_arret,
        ROW_NUMBER() OVER (
            PARTITION BY er.evenement
            ORDER BY er.geog_restaurant <-> a.geog
        ) AS rn_stop
    FROM event_to_restaurant er
    JOIN arrets_transport a ON ST_DWithin(er.geog_restaurant, a.geog, 300)
)
SELECT 
    evenement,
    evenement_description,
    evenement_adresse,
    date_debut,
    date_fin,
    restaurant_name,
    restaurant_description,
    specialites,
    periode_ouverte,
    note,
    review_count,
    arret_name,
    arret_id,
    distance_event_restaurant,
    distance_restaurant_arret,
    geog_evenement,
    geog_restaurant,
    geog_arret
FROM nearest_stops
WHERE rn_stop <= 5
ORDER BY distance_event_restaurant, distance_restaurant_arret;
"""

# %%
sql_vue_mat_restos_event = """DROP MATERIALIZED VIEW IF EXISTS restaurant_nearest_event CASCADE;

CREATE MATERIALIZED VIEW IF NOT EXISTS public.restaurant_nearest_event AS
WITH ranked_restaurants AS (
    SELECT 
        e.titre AS evenement,
        e.description AS evenement_description,
        e.adresse AS evenement_adresse,
        e.date_debut,
        e.date_fin,
        r.nom AS restaurant_name,
        r.google_note AS note,
        r.review_count AS review_count,
        r.description AS restaurant_description,
        r.specialites AS specialites,
        r.periode_ouverte AS periode_ouverte,
        r.geog AS geog_restaurant,
        ST_Distance(e.geog, r.geog) AS distance,
        e.geog AS geog_evenement,
        ROW_NUMBER() OVER (PARTITION BY e.titre ORDER BY e.geog <-> r.geog) AS rn
    FROM evenements_musicaux e
    JOIN restaurants r ON ST_DWithin(e.geog, r.geog, 400)
)
SELECT 
    evenement,
    evenement_description,
    evenement_adresse,
    date_debut,
    date_fin,
    restaurant_name,
    note,
    review_count,
    restaurant_description,
    specialites,
    periode_ouverte,
    geog_restaurant,
    distance,
    geog_evenement
FROM ranked_restaurants
WHERE rn <= 5;
"""

# %%
sql_vue_mat_nb_restos_arrets = """
DROP MATERIALIZED VIEW IF EXISTS nb_restaurants_par_arret CASCADE;
CREATE MATERIALIZED VIEW IF NOT EXISTS nb_restaurants_par_arret AS
SELECT arret_name, COUNT(*) AS nb_restaurants
FROM restaurant_nearest_stops
GROUP BY arret_name
ORDER BY nb_restaurants DESC;
"""

# %%
materialized_views = [
    sql_vue_mat_baignades_arrets,
    sql_vue_mat_events_arrets,
    sql_vue_mat_nb_evenement_arret,
    sql_vue_mat_restos_arrets,
    sql_mat_event_bon_resto_arret,
    sql_vue_mat_restos_event,
    sql_vue_mat_nb_restos_arrets,
    sql_vue_mat_baignade_meteo,
    sql_vue_mat_baignade_meilleurs_conditions,
    sql_vue_mat_baignade_temperature_moy,
    sql_vue_mat_baignade_arrets_temp
]

# %% [markdown]
# ## Mediator

# %%
import psycopg2
from sqlalchemy import create_engine, text

class Mediator:
    def __init__(self):
        self.engine = create_engine(
            f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}'
        )
        self.meteo_wrapper = OpenWeatherMapWrapper()
        self.restaurant_wrapper = RestaurantDataWrapper()
        self.transport_stop_wrapper = TransportStopDataInjector()
        self.music_event_wrapper = MusicEventDataInjector()
        self.baignade_wrapper = BaignadeDataInjector()
        self.transport_line_wrapper = TransportLineDataWrapper()
        self.transport_line_stops_wrapper = TransportLineStopsDataWrapper()
        # list map wrapper table name
        self.wrapper_list = [
            {
                "wrapper": self.meteo_wrapper,
                "table_name": "meteo_forecast"
            },
            {
                "wrapper": self.restaurant_wrapper,
                "table_name": "restaurants"
            },
            {
                "wrapper": self.transport_stop_wrapper,
                "table_name": "arrets_transport"
            },
            {
                "wrapper": self.music_event_wrapper,
                "table_name": "evenements_musicaux"
            },
            {
                "wrapper": self.baignade_wrapper,
                "table_name": "baignades"
            },
            {
                "wrapper": self.transport_line_wrapper,
                "table_name": "lignes_transport"
            },
            {
                "wrapper": self.transport_line_stops_wrapper,
                "table_name": "arrets_lignes_transport"
            }
        ]
        self.wrappers_to_refresh = [
            self.meteo_wrapper,
            self.restaurant_wrapper,
            self.transport_stop_wrapper,
            self.music_event_wrapper,
            self.baignade_wrapper,
        ]
        meteo_view_definitions = {
            "baignades_meteo" : sql_vue_mat_baignade_meteo,
            "baignades_best_conditions" : sql_vue_mat_baignade_meilleurs_conditions,
            "avg_temp_per_baignade" : sql_vue_mat_baignade_temperature_moy,
            "baignades_with_nearest_stop_and_temp" : sql_vue_mat_baignade_arrets_temp
        }
        events_view_definitions = {
            "evenements_arrets" : sql_vue_mat_events_arrets,
            "nb_evenements_par_arret" : sql_vue_mat_nb_evenement_arret,
            "mini_itineraire_event_good_restaurant_arret" : sql_mat_event_bon_resto_arret,
            "restaurant_nearest_event" : sql_vue_mat_restos_event
        }
        restaurant_view_definitions = {
            "restaurant_nearest_stops" : sql_vue_mat_restos_arrets,
            "nb_restaurants_par_arret" : sql_vue_mat_nb_restos_arrets,
            "restaurant_nearest_event" : sql_vue_mat_restos_event,
            "mini_itineraire_event_good_restaurant_arret" : sql_mat_event_bon_resto_arret
        }
        baigande_view_definitions = {
            "baignades_nearest_stops" : sql_vue_mat_baignades_arrets,
            "baignades_meteo" : sql_vue_mat_baignade_meteo,
            "baignades_best_conditions" : sql_vue_mat_baignade_meilleurs_conditions,
            "baignades_with_nearest_stop_and_temp" : sql_vue_mat_baignade_arrets_temp,
            "avg_temp_per_baignade" : sql_vue_mat_baignade_temperature_moy
        }
        arrets_view_definitions = {
            "baignades_nearest_stops" : sql_vue_mat_baignades_arrets,
            "evenements_arrets" : sql_vue_mat_events_arrets,
            "nb_evenements_par_arret" : sql_vue_mat_nb_evenement_arret,
            "restaurant_nearest_stops" : sql_vue_mat_restos_arrets,
            "nb_restaurants_par_arret" : sql_vue_mat_nb_restos_arrets,
            "mini_itineraire_event_good_restaurant_arret" : sql_mat_event_bon_resto_arret
        }
        
        
        self.wrapper_views_list = [
            {
                "wrapper": self.meteo_wrapper,
                "view_name": meteo_view_definitions
            },
            {
                "wrapper": self.music_event_wrapper,
                "view_name": events_view_definitions
            },
            {
                "wrapper": self.restaurant_wrapper,
                "view_name": restaurant_view_definitions
            },
            {
                "wrapper": self.baignade_wrapper,
                "view_name": baigande_view_definitions
            },
            {
                "wrapper": self.transport_stop_wrapper,
                "view_name": arrets_view_definitions
            }
        ]

    def add_postgis_extension(self):
        """Add PostGIS extension to the database."""
        with self.engine.begin() as connection:
            connection.execute(text("CREATE EXTENSION IF NOT EXISTS postgis;"))
            print("🧱 Extension PostGIS activée.")

    def create_tables(self):
        """Create tables (Drop and Recreate) using the wrappers."""
        with self.engine.begin() as conn:
            for wrapper in self.wrapper_list:
                # Drop the table if it exists
                conn.execute(text(f"DROP TABLE IF EXISTS {wrapper['table_name']} CASCADE;"))
                
                df = wrapper["wrapper"].run()
                df.to_sql(wrapper["table_name"], conn, if_exists="replace", index=False, dtype=wrapper["wrapper"].column_types)
                print(f"✅ Table '{wrapper['table_name']}' created or replaced.")
                
    def add_geography_columns(self):
        """Add geography columns to the tables if they do not exist."""
        with self.engine.begin() as connection:
            connection.execute(text("CREATE EXTENSION IF NOT EXISTS postgis;"))
            for table_name in ['restaurants', 'evenements_musicaux', 'baignades', 'arrets_transport']:
                connection.execute(text(f"""
                    ALTER TABLE {table_name}
                    ADD COLUMN IF NOT EXISTS geog geography(Point, 4326);
                """))
                connection.execute(text(f"""
                    UPDATE {table_name}
                    SET geog = ST_SetSRID(ST_MakePoint(longitude, latitude), 4326)
                    WHERE longitude IS NOT NULL AND latitude IS NOT NULL;
                """))
                # print(f"🧭 Geography column 'geog' added and populated for table '{table_name}'.")
    
    def refresh_data_wrapper(self, wrapper):
        """use to_sql replace table"""
        # get table_name from self.wrapper_list using wrapper["wrapper"]
        table_name = next((w["table_name"] for w in self.wrapper_list if w["wrapper"] == wrapper), None)
        
        df = wrapper.run()
        with self.engine.begin() as conn:
            # Drop the table if it exists
            conn.execute(text(f"DROP TABLE IF EXISTS {table_name} CASCADE;"))
            # Create the table and insert data
            df.to_sql(table_name, conn, if_exists="replace", index=False, dtype=wrapper.column_types)
            print(f"✅ Table '{table_name}' Data refreshed successfully.")
        
        self.add_geography_columns()
        self.refresh_views(wrapper)

        
    
    def drop_views(self, wrapper):
        # get view_name from self.wrapper_views_list using wrapper["wrapper"]
        wrapper_name = next((w for w in self.wrapper_views_list if w["wrapper"] == wrapper), None)
        view = wrapper_name["view_name"] if wrapper_name else None

        with self.engine.begin() as connection:
            for view_name, view_sql in view.items():
                print(f"⏳ Dropping view {view_name} (if it exists)...")
                # Drop the view if it exists. CASCADE will remove dependent objects.
                connection.execute(text(f"DROP MATERIALIZED VIEW IF EXISTS {view_name} CASCADE;"))

    def create_views(self, wrapper):
        # get view_name from self.wrapper_views_list using wrapper["wrapper"]
        wrapper_name = next((w for w in self.wrapper_views_list if w["wrapper"] == wrapper), None)
        view = wrapper_name["view_name"] if wrapper_name else None

        with self.engine.begin() as connection:
            for view_name, view_sql in view.items():
                print(f"⏳ Creating view {view_name}...")
                # Create the materialized view
                connection.execute(text(view_sql))
                print(f"✅ View {view_name} created successfully.")

    def refresh_views(self, wrapper):
        """Refresh all views by dropping and recreating them."""

        print("🔄 Refreshing views...")
        self.drop_views(wrapper)
        self.create_views(wrapper)
        print("✅ All views refreshed.")
    
    def refresh_all_materialized_views(self):
        """Refresh all materialized views."""
        with self.engine.begin() as connection:
            for view_sql in materialized_views:
                print(f"⏳ Refreshing view...")
                connection.execute(text(view_sql))
                print(f"✅ View refreshed successfully.")

# %%
mediator = Mediator()
mediator.add_postgis_extension()
mediator.create_tables()
mediator.add_geography_columns()
mediator.refresh_all_materialized_views()
# Out:
# 🧱 Extension PostGIS activée.
# ✅ Table 'meteo_forecast' created or replaced.
# 📄 Lecture du fichier CSV : restaurants_final.csv
# ✅ Table 'restaurants' created or replaced.
# 📄 Lecture du fichier CSV : cleaned_arrets.csv
# 🛠️ Splitting 'coordinates' into 'latitude' and 'longitude'...
# ✅ Table 'arrets_transport' created or replaced.
# 📄 Lecture du fichier CSV : evenement_musical_cleaned.csv
# Detected columns: ['titre', 'description', 'nom_lieu', 'adresse', 'ville', 'code_postal', 'latitude', 'longitude', 'date_debut', 'date_fin']
# ✅ Table 'evenements_musicaux' created or replaced.
# 📄 Lecture du fichier CSV : baignades.csv
# Detected columns: ['nom_du_site', 'categorie', 'baignade_surveillee', 'adresse', 'code_postal', 'ville', 'numero_de_telephone', 'longitude', 'latitude']
# ✅ Table 'baignades' created or replaced.
# 📄 Reading CSV file: lignes_transport_with_stop_ids.csv
# ✅ Table 'lignes_transport' created or replaced.
# 📄 Reading CSV file: lignes_transport_with_stop_ids.csv
# ✅ Table 'arrets_lignes_transport' created or replaced.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.
# ⏳ Refreshing view...
# ✅ View refreshed successfully.

# %% [markdown]
# ## The Following code needs to be executed within a python cron job with the desired frequency
# ### This will refresh data of the materialized views

# %%
# for wrapper in mediator.wrappers_to_refresh:
#     mediator.refresh_data_wrapper(wrapper["wrapper"])

# %% [markdown]
# ###  Unlike Baignades, Arrets and Restaurants
# ###  Meteo and Evenements Data are not generally static => They need daily ( or even hourly for meteo forecast ) refresh

# %%
# mediator.refresh_data_wrapper(mediator.meteo_wrapper)

# %% [markdown]
# ## Exploring Views and Queries

# %%
# %pip install folium shapely
# Out:
# Requirement already satisfied: folium in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (0.19.5)
# Requirement already satisfied: shapely in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (2.0.7)
# Requirement already satisfied: branca>=0.6.0 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nassi\downloads\projet integration\projet integration\env\lib\site-packages (from requests->folium) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# When the mediator receives a request involving tables
# - restaurants
# - evenements_musicaux
#
# it uses the materialized view
# > **restaurant_nearest_event**
# >
#
# Then, it applies the desired constraints on the view like the **exemple** below :
# - Distance between restaurants and events
# - Restaurants Note and Review Counts

# %%
from sqlalchemy import create_engine, types, text
import folium
from shapely import wkt


engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')


# SQL query converting geometry to WKT for restaurant and event.
sql = """
SELECT restaurant_name, 
    note, 
    review_count, 
    ST_AsText(geog_restaurant) as geog_restaurant,
    ST_AsText(geog_evenement) as geog_evenement,
    distance,
    evenement,
    date_debut, date_fin
FROM restaurant_nearest_event
WHERE note >= 4.0
  AND review_count >= 3 
  AND distance <= 100
  AND date_debut <= NOW()
  
ORDER BY evenement
"""

with engine.begin() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert the WKT strings into Shapely geometry objects using the correct column names.
df["restaurant_geom"] = df["geog_restaurant"].apply(wkt.loads)
df["event_geom"] = df["geog_evenement"].apply(wkt.loads)

# Create a Folium map centered on Marseille.
map_center = [43.296482, 5.36978]  # [latitude, longitude]
m = folium.Map(location=map_center, zoom_start=12)

# Loop through each record to add markers to the map.
for idx, row in df.iterrows():
    # Extract coordinates from the Shapely geometry objects.
    # Note: Shapely geometry has .x for longitude and .y for latitude.
    r_lon, r_lat = row["restaurant_geom"].x, row["restaurant_geom"].y
    e_lon, e_lat = row["event_geom"].x, row["event_geom"].y

    # Create a popup for the restaurant.
    popup_restaurant = (
        f"<b>{row['restaurant_name']}</b><br>"
        f"Rating: {row['note']} ⭐<br>"
        f"Reviews: {row['review_count']}<br>"
        f"Distance: {row['distance']:.2f} m"
    )
    folium.Marker(
        location=[r_lat, r_lon],
        popup=popup_restaurant,
        icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")
    ).add_to(m)

    # Create a popup for the event.
    popup_event = f"<b>Event:</b> {row['evenement']}"
    folium.Marker(
        location=[e_lat, e_lon],
        popup=popup_event,
        icon=folium.Icon(color="red", icon="music", prefix="fa")
    ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06cd0c8cce82ba35a5f29fefad7755c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06cd0c8cce82ba35a5f29fefad7755c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06cd0c8cce82ba35a5f29fefad7755c2 = L.map(
#                 &quot;map_06cd0c8cce82ba35a5f29fefad7755c2&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fa1198666c65424a2b75c4d86e2cf2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fa1198666c65424a2b75c4d86e2cf2c.addTo(map_06cd0c8cce82ba35a5f29fefad7755c2);
#
#
#             var marker_d5ea4b5ce62425a7b476c117e850134f = L.marker(
#                 [43.294402, 5.383732],
#                 {
# }
#             ).addTo(map_06cd0c8cce82ba35a5f29fefad7755c2);
#
#
#             var icon_5c5807b340d4f4b0d0f9c8e5e3f072bd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_221e2f7b7232db0d38d60a4ac6fa48ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddeaff9254cf9311c9e34c7d3f4b80b6 = $(`&lt;div id=&quot;html_ddeaff9254cf9311c9e34c7d3f4b80b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Le Café Vian&lt;/b&gt;&lt;br&gt;Rating: 4.3 ⭐&lt;br&gt;Reviews: 124&lt;br&gt;Distance: 26.18 m&lt;/div&gt;`)[0];
#                 popup_221e2f7b7232db0d38d60a4ac6fa48ce.setContent(html_ddeaff9254cf9311c9e34c7d3f4b80b6);
#
#
#
#         marker_d5ea4b5ce62425a7b476c117e850134f.bindPopup(popup_221e2f7b7232db0d38d60a4ac6fa48ce)
#         ;
#
#
#
#
#                 marker_d5ea4b5ce62425a7b476c117e850134f.setIcon(icon_5c5807b340d4f4b0d0f9c8e5e3f072bd);
#
#
#             var marker_6aa22841f4fddf7192aa22324a65bbd3 = L.marker(
#                 [43.29431, 5.383435],
#                 {
# }
#             ).addTo(map_06cd0c8cce82ba35a5f29fefad7755c2);
#
#
#             var icon_d38e2e389628171ec2770269c3a0c00f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;music&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8f6f27fb3ea0eb36a5f66a60e292fe03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c05b5ae5189780e00a3e6e25332fb7e6 = $(`&lt;div id=&quot;html_c05b5ae5189780e00a3e6e25332fb7e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Event:&lt;/b&gt; ⚠️COMPLET⚠️ MEZERG&lt;/div&gt;`)[0];
#                 popup_8f6f27fb3ea0eb36a5f66a60e292fe03.setContent(html_c05b5ae5189780e00a3e6e25332fb7e6);
#
#
#
#         marker_6aa22841f4fddf7192aa22324a65bbd3.bindPopup(popup_8f6f27fb3ea0eb36a5f66a60e292fe03)
#         ;
#
#
#
#
#                 marker_6aa22841f4fddf7192aa22324a65bbd3.setIcon(icon_d38e2e389628171ec2770269c3a0c00f);
#
#
#             var marker_a0c39c186a5feb6f7fe8ab054e973b05 = L.marker(
#                 [43.294321, 5.383916],
#                 {
# }
#             ).addTo(map_06cd0c8cce82ba35a5f29fefad7755c2);
#
#
#             var icon_f2893c19930faf87d872891af9ad5331 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b6d036d145706275240686256994c9ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37e9d113a951b4ed35101ce0e4bc5e20 = $(`&lt;div id=&quot;html_37e9d113a951b4ed35101ce0e4bc5e20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;La Marche à suivre&lt;/b&gt;&lt;br&gt;Rating: 4.1 ⭐&lt;br&gt;Reviews: 128&lt;br&gt;Distance: 39.05 m&lt;/div&gt;`)[0];
#                 popup_b6d036d145706275240686256994c9ac.setContent(html_37e9d113a951b4ed35101ce0e4bc5e20);
#
#
#
#         marker_a0c39c186a5feb6f7fe8ab054e973b05.bindPopup(popup_b6d036d145706275240686256994c9ac)
#         ;
#
#
#
#
#                 marker_a0c39c186a5feb6f7fe8ab054e973b05.setIcon(icon_f2893c19930faf87d872891af9ad5331);
#
#
#             var marker_c9dc8b5b8c8ef6060636e950979e0a37 = L.marker(
#                 [43.29431, 5.3

# %% [markdown]
# When the mediator receives a request involving tables
# - arrets
# - evenements_musicaux
#
# it uses the materialized view
# > **evenements_arrets**
# >
#
# Then, it applies the desired constraints on the view like the **exemple** below :
# - Distance between arrets and events inferior or equal to 50 meters >
# - Evenement has not started yet

# %%
# Create engine
engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# Query from the materialized view
sql = """
SELECT evenement,
       evenement_description,
       evenement_lieu,
       debut_evenement,
       fin_evenement,
       arret_name,
       ST_AsText(geog_evenement) AS geog_evenement,
       ST_AsText(geog_arret) AS geog_arret,
       distance
FROM evenements_arrets
WHERE debut_evenement <= NOW() AND distance <= 50
ORDER BY evenement, distance
"""

# Execute the query
with engine.connect() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert geometry columns
df["event_geom"] = df["geog_evenement"].apply(wkt.loads)
df["arret_geom"] = df["geog_arret"].apply(wkt.loads)

# Create a Folium map centered on Marseille
map_center = [43.296482, 5.36978]
m = folium.Map(location=map_center, zoom_start=12)

# Track which events have been mapped to avoid duplicate event markers
plotted_events = set()

# Add markers for events and their nearest stops
for _, row in df.iterrows():
    event_coords = [row["event_geom"].y, row["event_geom"].x]
    stop_coords = [row["arret_geom"].y, row["arret_geom"].x]

    # Add the event marker only once
    if row["evenement"] not in plotted_events:
        popup_event = (
            f"<b>Event:</b> {row['evenement']}<br>"
            f"<b>Lieu:</b> {row['evenement_lieu']}<br>"
            f"<b>Début:</b> {row['debut_evenement']}<br>"
            f"<b>Fin:</b> {row['fin_evenement']}"
        )
        folium.Marker(
            location=event_coords,
            popup=popup_event,
            icon=folium.Icon(color="red", icon="music", prefix="fa")
        ).add_to(m)
        plotted_events.add(row["evenement"])

    # Add marker for each nearby stop
    popup_stop = (
        f"<b>Arret:</b> {row['arret_name']}<br>"
        f"<b>Distance:</b> {row['distance']:.1f} m"
    )
    folium.Marker(
        location=stop_coords,
        popup=popup_stop,
        icon=folium.Icon(color="green", icon="bus", prefix="fa")
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1500b4984bb911c70711a7ecd1f09ab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1500b4984bb911c70711a7ecd1f09ab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1500b4984bb911c70711a7ecd1f09ab0 = L.map(
#                 &quot;map_1500b4984bb911c70711a7ecd1f09ab0&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d36845d87a681892108bd3fc4bcb80ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d36845d87a681892108bd3fc4bcb80ea.addTo(map_1500b4984bb911c70711a7ecd1f09ab0);
#
#
#             var marker_d5b20fdae3460871997eb14582574973 = L.marker(
#                 [43.296497, 5.371989],
#                 {
# }
#             ).addTo(map_1500b4984bb911c70711a7ecd1f09ab0);
#
#
#             var icon_ff305a9299da556f5707c72ae2a03d23 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;music&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1528d82f9124dd41e70f1e758c760cb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c5d741ad0c53ab3b3b2820d32a68de7 = $(`&lt;div id=&quot;html_4c5d741ad0c53ab3b3b2820d32a68de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Event:&lt;/b&gt; Alert O Jazz&lt;br&gt;&lt;b&gt;Lieu:&lt;/b&gt; la Caravelle&lt;br&gt;&lt;b&gt;Début:&lt;/b&gt; 2025-04-18 21:00:00&lt;br&gt;&lt;b&gt;Fin:&lt;/b&gt; 2025-04-18 23:59:00&lt;/div&gt;`)[0];
#                 popup_1528d82f9124dd41e70f1e758c760cb0.setContent(html_4c5d741ad0c53ab3b3b2820d32a68de7);
#
#
#
#         marker_d5b20fdae3460871997eb14582574973.bindPopup(popup_1528d82f9124dd41e70f1e758c760cb0)
#         ;
#
#
#
#
#                 marker_d5b20fdae3460871997eb14582574973.setIcon(icon_ff305a9299da556f5707c72ae2a03d23);
#
#
#             var marker_0dbb03a8efd9d83f569ff3d3690af77b = L.marker(
#                 [43.296763, 5.371628],
#                 {
# }
#             ).addTo(map_1500b4984bb911c70711a7ecd1f09ab0);
#
#
#             var icon_9c70f063451b2dc2de076de8c2989d6b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bus&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4ffcb58c255c689ddfc5357cc0d0655e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d096995872f67d9759e7f791d0e0f45d = $(`&lt;div id=&quot;html_d096995872f67d9759e7f791d0e0f45d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arret:&lt;/b&gt; Bonneterie&lt;br&gt;&lt;b&gt;Distance:&lt;/b&gt; 41.6 m&lt;/div&gt;`)[0];
#                 popup_4ffcb58c255c689ddfc5357cc0d0655e.setContent(html_d096995872f67d9759e7f791d0e0f45d);
#
#
#
#         marker_0dbb03a8efd9d83f569ff3d3690af77b.bindPopup(popup_4ffcb58c255c689ddfc5357cc0d0655e)
#         ;
#
#
#
#
#                 marker_0dbb03a8efd9d83f569ff3d3690af77b.setIcon(icon_9c70f063451b2dc2de076de8c2989d6b);
#
#
#             var marker_c45c5947e7a823b4a1886372670e2bf2 = L.marker(
#                 [43.291527, 5.384469],
#                 {
# }
#             ).addTo(map_1500b4984bb911c70711a7ecd1f09ab0);
#
#
#             var icon_4499a3274db4484b10db30f3f5c40076 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;music&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_201959af31cfb61498cb8c9b3d46317c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07fc5aa470d873dcaa740ef1f3431fd4 = $(`&lt;div id=&quot;html_07fc5aa470d873dcaa740ef1f3431fd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Event:&lt;/b&gt; ANALOG DAKAR CLUB&lt;br&gt;&lt;b&gt;Lieu:&lt;/b&gt; La Dame du Mont&lt;br&gt;&lt;b&gt;Début:&lt;/b&gt; 2025-04-11 21:30:00&lt;br&gt;&lt;b&gt;Fin:&lt;/b&gt; 2025-04-12 02:00:00&lt;/div&gt;`)[0];
#                 popup_201959af31cfb61498cb8c9b3d46317c.setContent(html_07fc5aa470d873dcaa740ef1f3431fd4);
#
#
#
#         marker_c45c5947e7a823b4a1886372670e2bf2.bindPopup(popup_201959af31cfb61498cb8c9b3d46317c)
#         ;

# %% [markdown]
# When the mediator receives a request involving tables
# - arrets
# - restaurants
#
# it uses the materialized view
# > **restaurant_nearest_stops**
# >
#
# Then, it applies the desired constraints on the view like the **exemple** below :
# - Distance between arrets and restos inferior or equal to 50 meters >
# - Good restaurants only

# %%
engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# SQL query using the materialized view
sql = """
SELECT restaurant_name,
       restaurant_description,
       specialites,
       periode_ouverte,
       note,
       review_count,
       ST_AsText(geog_restaurant) AS geog_restaurant,
       arret_name,
       ST_AsText(geog_arret) AS geog_arret,
       distance,
       stop_rank
FROM restaurant_nearest_stops
WHERE note >= 4.0 AND review_count >= 3 AND distance <=50
ORDER BY restaurant_name, stop_rank
"""

# Execute the query
with engine.connect() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert geometry columns
df["restaurant_geom"] = df["geog_restaurant"].apply(wkt.loads)
df["arret_geom"] = df["geog_arret"].apply(wkt.loads)

# Initialize map centered on Marseille
map_center = [43.296482, 5.36978]
m = folium.Map(location=map_center, zoom_start=13)

# Keep track of plotted restaurants to avoid duplicate markers
plotted_restaurants = set()

# Add markers
for _, row in df.iterrows():
    r_coords = [row["restaurant_geom"].y, row["restaurant_geom"].x]
    a_coords = [row["arret_geom"].y, row["arret_geom"].x]

    # Plot restaurant only once
    if row["restaurant_name"] not in plotted_restaurants:
        popup_restaurant = (
            f"<b>{row['restaurant_name']}</b><br>"
            f"⭐ {row['note']} ({row['review_count']} avis)<br>"
            f"<i>{row['specialites']}</i><br>"
            f"<b>Ouverture:</b> {row['periode_ouverte']}<br>"
            f"<br>{row['restaurant_description']}"
        )
        folium.Marker(
            location=r_coords,
            popup=popup_restaurant,
            icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")
        ).add_to(m)
        plotted_restaurants.add(row["restaurant_name"])

    # Plot each nearby stop
    popup_stop = (
        f"<b>Arrêt:</b> {row['arret_name']}<br>"
        f"<b>Distance:</b> {row['distance']:.1f} m"
    )
    folium.Marker(
        location=a_coords,
        popup=popup_stop,
        icon=folium.Icon(color="green", icon="bus", prefix="fa")
    ).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e8c95cf24d14402507c6d26761706e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e8c95cf24d14402507c6d26761706e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e8c95cf24d14402507c6d26761706e5 = L.map(
#                 &quot;map_9e8c95cf24d14402507c6d26761706e5&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3acac012d5c83a576a046b1ae522c7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3acac012d5c83a576a046b1ae522c7a.addTo(map_9e8c95cf24d14402507c6d26761706e5);
#
#
#             var marker_dfdcf2af39e2f8136ae87bed0930511e = L.marker(
#                 [43.292087, 5.384311],
#                 {
# }
#             ).addTo(map_9e8c95cf24d14402507c6d26761706e5);
#
#
#             var icon_e46e1660a3b965b339a4c236c3f0f4c9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_36cae8861b6ee00ec303afe057519619 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39a691ba9972d5a0f35bc0822592c3c6 = $(`&lt;div id=&quot;html_39a691ba9972d5a0f35bc0822592c3c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Beans Marseille&lt;/b&gt;&lt;br&gt;⭐ 4.0 (44 avis)&lt;br&gt;&lt;i&gt;Plats végétariens&lt;/i&gt;&lt;br&gt;&lt;b&gt;Ouverture:&lt;/b&gt; Du 02/01 au 31/12/2024, tous les lundis, mercredis, jeudis, vendredis, samedis et dimanches de 8h30 à 16h. Service en continu la semaine de 8:30 à 16:00 puis happy hours le soir.
#  Ouvert samedi de 10h30 à 15h.
#  Ouvert dimanche de 10h30 à 15h.
#  Ouvert lundi.&lt;br&gt;&lt;br&gt;Restaurant proposant des petits-déjeuners anglo-saxons servis toute la journée et des brunch le week-end dans une atmosphère conviviale. Inspiré des restaurants “all-day breakfast” de Londres.&lt;/div&gt;`)[0];
#                 popup_36cae8861b6ee00ec303afe057519619.setContent(html_39a691ba9972d5a0f35bc0822592c3c6);
#
#
#
#         marker_dfdcf2af39e2f8136ae87bed0930511e.bindPopup(popup_36cae8861b6ee00ec303afe057519619)
#         ;
#
#
#
#
#                 marker_dfdcf2af39e2f8136ae87bed0930511e.setIcon(icon_e46e1660a3b965b339a4c236c3f0f4c9);
#
#
#             var marker_d8f88149e43194b6137859bb1caba2c3 = L.marker(
#                 [43.29249, 5.384091],
#                 {
# }
#             ).addTo(map_9e8c95cf24d14402507c6d26761706e5);
#
#
#             var icon_0500d9bf652d129959787b623e4a9e22 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bus&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fa4903d9872edd312ae74848c2d96ecd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28ccf01bb5dec83848ee628bfcbc4882 = $(`&lt;div id=&quot;html_28ccf01bb5dec83848ee628bfcbc4882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arrêt:&lt;/b&gt; Métro Notre Dame du Mont&lt;br&gt;&lt;b&gt;Distance:&lt;/b&gt; 48.2 m&lt;/div&gt;`)[0];
#                 popup_fa4903d9872edd312ae74848c2d96ecd.setContent(html_28ccf01bb5dec83848ee628bfcbc4882);
#
#
#
#         marker_d8f88149e43194b6137859bb1caba2c3.bindPopup(popup_fa4903d9872edd312ae74848c2d96ecd)
#         ;
#
#
#
#
#                 marker_d8f88149e43194b6137859bb1caba2c3.setIcon(icon_0500d9bf652d129959787b623e4a9e22);
#
#
#             var marker_e40b85a4302a66e07f36ff2db0f5a985 = L.marker(
#                 [43.291751, 5.384408],
#                 {
# }
#             ).addTo(map_9e8c95cf24d14402507c6d26761706e5);
#
#
#             var icon_1bd1e795a46293313be7c64c6ff2e3f7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bus&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_542f9622241471e8df94c59a94aba439 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e970ff1b564744fa7315b0c665548a0 = $(`&lt;div id=&quot;html_8e970ff1b564744fa7315b0c665548a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arrêt:&lt;/b&gt; Lodi Fontange&lt;br&

# %% [markdown]
# When the mediator receives a request involving tables
# - arrets
# - restaurants
# - evenements_musicaux
#
# it uses the materialized view
# > **mini_itineraire_event_good_restaurant_arret**
# >
#
# Then, it applies the desired constraints on the view like the **exemple** below :
# - Distance between arrets and restos, restos and events inferior or equal to 100 meters >
# - Events didnt finish yet

# %%
engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# Query from the materialized view
sql = """
SELECT 
    evenement,
    evenement_description,
    evenement_adresse,
    date_debut,
    date_fin,
    restaurant_name,
    restaurant_description,
    specialites,
    periode_ouverte,
    note,
    review_count,
    arret_name,
    arret_id,
    distance_event_restaurant,
    distance_restaurant_arret,
    ST_AsText(geog_evenement) AS geog_evenement,
    ST_AsText(geog_restaurant) AS geog_restaurant,
    ST_AsText(geog_arret) AS geog_arret
FROM mini_itineraire_event_good_restaurant_arret
WHERE date_fin >= NOW() AND distance_event_restaurant <=100 AND distance_restaurant_arret <= 100
ORDER BY distance_event_restaurant, distance_restaurant_arret
"""

# Load data
with engine.connect() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert geometries
df["geom_event"] = df["geog_evenement"].apply(wkt.loads)
df["geom_restaurant"] = df["geog_restaurant"].apply(wkt.loads)
df["geom_stop"] = df["geog_arret"].apply(wkt.loads)

# Create map
m = folium.Map(location=[43.296482, 5.36978], zoom_start=13)

# Track which event/resto already plotted
plotted_events = set()
plotted_restaurants = set()

# Add markers
for _, row in df.iterrows():
    # Extract coords
    e_lat, e_lon = row["geom_event"].y, row["geom_event"].x
    r_lat, r_lon = row["geom_restaurant"].y, row["geom_restaurant"].x
    s_lat, s_lon = row["geom_stop"].y, row["geom_stop"].x

    # Event marker
    if row["evenement"] not in plotted_events:
        popup_event = (
            f"<b>{row['evenement']}</b><br>"
            f"<i>{row['evenement_description']}</i><br>"
            f"<b>Adresse:</b> {row['evenement_adresse']}<br>"
            f"<b>Du:</b> {row['date_debut']}<br>"
            f"<b>Au:</b> {row['date_fin']}"
        )
        folium.Marker(
            location=[e_lat, e_lon],
            popup=popup_event,
            icon=folium.Icon(color="red", icon="music", prefix="fa")
        ).add_to(m)
        plotted_events.add(row["evenement"])

    # Restaurant marker
    if row["restaurant_name"] not in plotted_restaurants:
        popup_restaurant = (
            f"<b>{row['restaurant_name']}</b><br>"
            f"<i>{row['specialites']}</i><br>"
            f"⭐ {row['note']} ({row['review_count']} avis)<br>"
            f"<b>Ouverture:</b> {row['periode_ouverte']}<br>"
            f"{row['restaurant_description']}"
        )
        folium.Marker(
            location=[r_lat, r_lon],
            popup=popup_restaurant,
            icon=folium.Icon(color="blue", icon="cutlery", prefix="fa")
        ).add_to(m)
        plotted_restaurants.add(row["restaurant_name"])

    # Transport stop marker
    popup_stop = (
        f"<b>Arrêt:</b> {row['arret_name']}<br>"
        f"<b>Distance restaurant → arrêt:</b> {row['distance_restaurant_arret']:.1f} m"
    )
    folium.Marker(
        location=[s_lat, s_lon],
        popup=popup_stop,
        icon=folium.Icon(color="green", icon="bus", prefix="fa")
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38c3435239927813d88d8443cb34bab1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38c3435239927813d88d8443cb34bab1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38c3435239927813d88d8443cb34bab1 = L.map(
#                 &quot;map_38c3435239927813d88d8443cb34bab1&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4778c29fd198ccf6d44b2e943a27179 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4778c29fd198ccf6d44b2e943a27179.addTo(map_38c3435239927813d88d8443cb34bab1);
#
#
#             var marker_f5a64b01d0b5726d212642fb165d726f = L.marker(
#                 [43.296497, 5.371989],
#                 {
# }
#             ).addTo(map_38c3435239927813d88d8443cb34bab1);
#
#
#             var icon_b55a164274c85c8e90baf0f7d92f4017 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;music&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_08966dcb3eba9e1f27273fdc39353608 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_254714f1ed0f8104043b5dc8059a2601 = $(`&lt;div id=&quot;html_254714f1ed0f8104043b5dc8059a2601&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Les Boucaniers du Swing&lt;/b&gt;&lt;br&gt;&lt;i&gt;♫♫♫&lt;/i&gt;&lt;br&gt;&lt;b&gt;Adresse:&lt;/b&gt; 34 quai du Port, 13002 Marseille&lt;br&gt;&lt;b&gt;Du:&lt;/b&gt; 2025-05-02 21:00:00&lt;br&gt;&lt;b&gt;Au:&lt;/b&gt; 2025-05-02 23:59:00&lt;/div&gt;`)[0];
#                 popup_08966dcb3eba9e1f27273fdc39353608.setContent(html_254714f1ed0f8104043b5dc8059a2601);
#
#
#
#         marker_f5a64b01d0b5726d212642fb165d726f.bindPopup(popup_08966dcb3eba9e1f27273fdc39353608)
#         ;
#
#
#
#
#                 marker_f5a64b01d0b5726d212642fb165d726f.setIcon(icon_b55a164274c85c8e90baf0f7d92f4017);
#
#
#             var marker_b065978bcb545e72ea245d2bd59859a2 = L.marker(
#                 [43.2965, 5.371989],
#                 {
# }
#             ).addTo(map_38c3435239927813d88d8443cb34bab1);
#
#
#             var icon_94d5598b2026a45c6b24d9391c3eada0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e5ae28df9909af96770f46024b196720 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19313cca10e7e30e38d93c396ee6b459 = $(`&lt;div id=&quot;html_19313cca10e7e30e38d93c396ee6b459&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Restaurant La Caravelle&lt;/b&gt;&lt;br&gt;&lt;i&gt;Cuisine méditerranéenne, Cuisine traditionnelle française, Cuisine Provençale, Propose des plats &quot;fait maison&quot;&lt;/i&gt;&lt;br&gt;⭐ 4.1 (279 avis)&lt;br&gt;&lt;b&gt;Ouverture:&lt;/b&gt; Toute l&#x27;année, tous les jours. Ouvert tous les jours à midi, et le soir lors de concerts.&lt;br&gt;Une cuisine marseillaise fait maison, avec un service brasserie restaurant traditionnelle et des classiques revisités au gré des saisons.&lt;/div&gt;`)[0];
#                 popup_e5ae28df9909af96770f46024b196720.setContent(html_19313cca10e7e30e38d93c396ee6b459);
#
#
#
#         marker_b065978bcb545e72ea245d2bd59859a2.bindPopup(popup_e5ae28df9909af96770f46024b196720)
#         ;
#
#
#
#
#                 marker_b065978bcb545e72ea245d2bd59859a2.setIcon(icon_94d5598b2026a45c6b24d9391c3eada0);
#
#
#             var marker_57e2318f4ab7520208b5a390728e60ac = L.marker(
#                 [43.296763, 5.371628],
#                 {
# }
#             ).addTo(map_38c3435239927813d88d8443cb34bab1);
#
#
#             var icon_38b1151952056da11d23c3a0025640ce = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bus&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a627077587387eb3b0d2010e3933309f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9e90738a17d3647d8f41e18588a680e = $(`&lt;div id=&quot;html_b9e90738a17d3647d8f41e18588a680e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;A

# %% [markdown]
# When the mediator receives a request involving tables
# - baignades
# - arrets
#
# it uses the materialized view
# > **baignades_nearest_stops**
# >

# %%
engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# Query from the materialized view
sql = """
SELECT 
    nom,
    categorie,
    baignade_surveillee,
    adresse,
    numero_de_telephone,
    arret_name,
    arret_id,
    ST_AsText(geog_baignade) AS geog_baignade,
    ST_AsText(geog_arret) AS geog_arret,
    distance
FROM baignades_nearest_stops
ORDER BY nom
"""

# Load data
with engine.connect() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert geometries
df["geom_baignade"] = df["geog_baignade"].apply(wkt.loads)
df["geom_stop"] = df["geog_arret"].apply(wkt.loads)

# Create map
m = folium.Map(location=[43.296482, 5.36978], zoom_start=12)

# Add markers
for _, row in df.iterrows():
    b_lat, b_lon = row["geom_baignade"].y, row["geom_baignade"].x
    s_lat, s_lon = row["geom_stop"].y, row["geom_stop"].x

    # Bathing site marker
    popup_baignade = (
        f"<b>{row['nom']}</b><br>"
        f"<i>{row['categorie']}</i><br>"
        f"<b>Surveillée:</b> {row['baignade_surveillee']}<br>"
        f"<b>Adresse:</b> {row['adresse']}<br>"
        f"<b>Tél:</b> {row['numero_de_telephone']}"
    )
    folium.Marker(
        location=[b_lat, b_lon],
        popup=popup_baignade,
        icon=folium.Icon(color="cadetblue", icon="tint", prefix="fa")
    ).add_to(m)

    # Transport stop marker
    popup_stop = (
        f"<b>Arrêt:</b> {row['arret_name']}<br>"
        f"<b>Distance:</b> {row['distance']:.1f} m"
    )
    folium.Marker(
        location=[s_lat, s_lon],
        popup=popup_stop,
        icon=folium.Icon(color="green", icon="bus", prefix="fa")
    ).add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f53d0542e9098d7b67c0926a3e4994ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f53d0542e9098d7b67c0926a3e4994ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f53d0542e9098d7b67c0926a3e4994ad = L.map(
#                 &quot;map_f53d0542e9098d7b67c0926a3e4994ad&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1c4d3d28ead30432aacd08e7159d608 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1c4d3d28ead30432aacd08e7159d608.addTo(map_f53d0542e9098d7b67c0926a3e4994ad);
#
#
#             var marker_23f611c45999c243d692ef7d1816d555 = L.marker(
#                 [43.239695, 5.362287],
#                 {
# }
#             ).addTo(map_f53d0542e9098d7b67c0926a3e4994ad);
#
#
#             var icon_bbc3545606e2c9bf37af0729836d21fe = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c69a4315110170f76322783e61182423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08b346c3636f798bfbe017798baf9b3f = $(`&lt;div id=&quot;html_08b346c3636f798bfbe017798baf9b3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Anse des Phoceens&lt;/b&gt;&lt;br&gt;&lt;i&gt;Plages&lt;/i&gt;&lt;br&gt;&lt;b&gt;Surveillée:&lt;/b&gt; False&lt;br&gt;&lt;b&gt;Adresse:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Tél:&lt;/b&gt; None&lt;/div&gt;`)[0];
#                 popup_c69a4315110170f76322783e61182423.setContent(html_08b346c3636f798bfbe017798baf9b3f);
#
#
#
#         marker_23f611c45999c243d692ef7d1816d555.bindPopup(popup_c69a4315110170f76322783e61182423)
#         ;
#
#
#
#
#                 marker_23f611c45999c243d692ef7d1816d555.setIcon(icon_bbc3545606e2c9bf37af0729836d21fe);
#
#
#             var marker_c6b2ffaa6ecadffe27e07d17978eadf1 = L.marker(
#                 [43.238692, 5.365196],
#                 {
# }
#             ).addTo(map_f53d0542e9098d7b67c0926a3e4994ad);
#
#
#             var icon_96566d74d25ffb8bf50572f1a55c950a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bus&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_04b1b7ca163db236caed13fe2bd4f1d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1726c4656fa7351dcf3edb731bb1ed08 = $(`&lt;div id=&quot;html_1726c4656fa7351dcf3edb731bb1ed08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arrêt:&lt;/b&gt; Engalière&lt;br&gt;&lt;b&gt;Distance:&lt;/b&gt; 261.2 m&lt;/div&gt;`)[0];
#                 popup_04b1b7ca163db236caed13fe2bd4f1d0.setContent(html_1726c4656fa7351dcf3edb731bb1ed08);
#
#
#
#         marker_c6b2ffaa6ecadffe27e07d17978eadf1.bindPopup(popup_04b1b7ca163db236caed13fe2bd4f1d0)
#         ;
#
#
#
#
#                 marker_c6b2ffaa6ecadffe27e07d17978eadf1.setIcon(icon_96566d74d25ffb8bf50572f1a55c950a);
#
#
#             var marker_be4bdfa3354ee88811debe343603bb74 = L.marker(
#                 [43.237535, 5.360873],
#                 {
# }
#             ).addTo(map_f53d0542e9098d7b67c0926a3e4994ad);
#
#
#             var icon_ae0fe94b7ea83b50e01d6c518f14c16d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3c2211272b1896fe456d35cdbbbdebe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b34f7d323568dd9e4cb36b893d572a1d = $(`&lt;div id=&quot;html_b34f7d323568dd9e4cb36b893d572a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Anse des Sablettes (plage du Colombet)&lt;/b&gt;&lt;br&gt;&lt;i&gt;Plages&lt;/i&gt;&lt;br&gt;&lt;b&gt;Surveillée:&lt;/b&gt; False&lt;br&gt;&lt;b&gt;Adresse:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Tél:&lt;/b&gt; None&lt;/div&gt;`)[0];
#                 popup_3c2211272b1896fe456d35cdbbbdebe8.setContent(html_b34f7d323568dd9e4cb36b893d572a1d);
#
#
#
#         marker_be4bdfa3354ee88811debe343603bb74.bindPopup(popup_3c2211272b1896fe456d35cdbbbdebe8)

# %%
engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# Query the most recent forecast per site
sql = """
SELECT DISTINCT ON (nom_du_site)
    nom_du_site,
    categorie,
    baignade_surveillee,
    adresse,
    numero_de_telephone,
    ST_AsText(geog_baignade) AS geog_baignade,
    forecast_time,
    temperature,
    humidite,
    vitesse_vent,
    description_meteo
FROM baignades_meteo
WHERE forecast_time >= NOW()
ORDER BY nom_du_site, forecast_time ASC
"""

with engine.connect() as conn:
    df = pd.read_sql_query(text(sql), conn)

# Convert geometry
df["geom_baignade"] = df["geog_baignade"].apply(wkt.loads)

# Base map
m = folium.Map(location=[43.296482, 5.36978], zoom_start=12)

# Add bathing sites with weather
for _, row in df.iterrows():
    lat, lon = row["geom_baignade"].y, row["geom_baignade"].x

    popup = (
        f"<b>{row['nom_du_site']}</b><br>"
        f"<i>{row['categorie']}</i><br>"
        f"<b>Surveillée:</b> {row['baignade_surveillee']}<br>"
        f"<b>Adresse:</b> {row['adresse']}<br>"
        f"<b>Tél:</b> {row['numero_de_telephone']}<br><br>"
        f"<b>Météo:</b> {row['description_meteo']}<br>"
        f"🌡 {row['temperature']} °C<br>"
        f"💧 {row['humidite']} %<br>"
        f"💨 {row['vitesse_vent']} km/h<br>"
        f"<small>Prévu à: {row['forecast_time']}</small>"
    )

    folium.Marker(
        location=[lat, lon],
        popup=popup,
        icon=folium.Icon(color="lightblue", icon="cloud", prefix="fa")
    ).add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d58a2f6c2afd982ebecd65920928394 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d58a2f6c2afd982ebecd65920928394&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d58a2f6c2afd982ebecd65920928394 = L.map(
#                 &quot;map_5d58a2f6c2afd982ebecd65920928394&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5352d10688728448ba6464b5be86008a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5352d10688728448ba6464b5be86008a.addTo(map_5d58a2f6c2afd982ebecd65920928394);
#
#
#             var marker_0c179dc5f6e558aefaa2c95ec5641c0b = L.marker(
#                 [43.239695, 5.362287],
#                 {
# }
#             ).addTo(map_5d58a2f6c2afd982ebecd65920928394);
#
#
#             var icon_6ed2f8ce4cccd1e742441474d48d690a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fa3c425ba21f898eb7bda4729a027273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_588fd8c03b675fe35571459c0a82e40c = $(`&lt;div id=&quot;html_588fd8c03b675fe35571459c0a82e40c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Anse des Phoceens&lt;/b&gt;&lt;br&gt;&lt;i&gt;Plages&lt;/i&gt;&lt;br&gt;&lt;b&gt;Surveillée:&lt;/b&gt; False&lt;br&gt;&lt;b&gt;Adresse:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Tél:&lt;/b&gt; None&lt;br&gt;&lt;br&gt;&lt;b&gt;Météo:&lt;/b&gt; overcast clouds&lt;br&gt;🌡 11.6 °C&lt;br&gt;💧 62 %&lt;br&gt;💨 5.06 km/h&lt;br&gt;&lt;small&gt;Prévu à: 2025-04-18 22:00:00+00:00&lt;/small&gt;&lt;/div&gt;`)[0];
#                 popup_fa3c425ba21f898eb7bda4729a027273.setContent(html_588fd8c03b675fe35571459c0a82e40c);
#
#
#
#         marker_0c179dc5f6e558aefaa2c95ec5641c0b.bindPopup(popup_fa3c425ba21f898eb7bda4729a027273)
#         ;
#
#
#
#
#                 marker_0c179dc5f6e558aefaa2c95ec5641c0b.setIcon(icon_6ed2f8ce4cccd1e742441474d48d690a);
#
#
#             var marker_509fca03868774d9f9bf377c50e5387f = L.marker(
#                 [43.237535, 5.360873],
#                 {
# }
#             ).addTo(map_5d58a2f6c2afd982ebecd65920928394);
#
#
#             var icon_ada58d11a2c97ae30513400adcedaaaf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a085f4e96aad64ff9b39486ef1567848 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab340354a3dcdebf1ce12c33ca3d7ef5 = $(`&lt;div id=&quot;html_ab340354a3dcdebf1ce12c33ca3d7ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Anse des Sablettes (plage du Colombet)&lt;/b&gt;&lt;br&gt;&lt;i&gt;Plages&lt;/i&gt;&lt;br&gt;&lt;b&gt;Surveillée:&lt;/b&gt; False&lt;br&gt;&lt;b&gt;Adresse:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Tél:&lt;/b&gt; None&lt;br&gt;&lt;br&gt;&lt;b&gt;Météo:&lt;/b&gt; overcast clouds&lt;br&gt;🌡 11.6 °C&lt;br&gt;💧 62 %&lt;br&gt;💨 5.06 km/h&lt;br&gt;&lt;small&gt;Prévu à: 2025-04-18 22:00:00+00:00&lt;/small&gt;&lt;/div&gt;`)[0];
#                 popup_a085f4e96aad64ff9b39486ef1567848.setContent(html_ab340354a3dcdebf1ce12c33ca3d7ef5);
#
#
#
#         marker_509fca03868774d9f9bf377c50e5387f.bindPopup(popup_a085f4e96aad64ff9b39486ef1567848)
#         ;
#
#
#
#
#                 marker_509fca03868774d9f9bf377c50e5387f.setIcon(icon_ada58d11a2c97ae30513400adcedaaaf);
#
#
#             var marker_251890166cd73f169946ae84fa0643e3 = L.marker(
#                 [43.241082, 5.362628],
#                 {
# }
#             ).addTo(map_5d58a2f6c2afd982ebecd65920928394);
#
#
#             var icon_37cee523ddf3b0221b2bab62b186e976 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cefa6a1aab0bd3ca4a354e5dd1ddf9ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef2cca908d567c6bb2f1767693326b5 = $(`&lt;div id=&quot;html_eef2cca908d567c6bb2f1767693326b5&quot;

# %%
engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# SQL query
sql = """
SELECT 
    nom,
    arret_name,
    categorie,
    baignade_surveillee,
    adresse,
    numero_de_telephone,
    avg_temp,
    ST_AsText(geog_baignade) AS geog_baignade,
    ST_AsText(geog_arret) AS geog_arret
FROM baignades_with_nearest_stop_and_temp
"""

# Fetch the data
with engine.begin() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert WKT to Shapely geometries
df["baignade_geom"] = df["geog_baignade"].apply(wkt.loads)
df["arret_geom"] = df["geog_arret"].apply(wkt.loads)

# Create map centered on Marseille
map_center = [43.296482, 5.36978]
m = folium.Map(location=map_center, zoom_start=12)

# Plot data
for _, row in df.iterrows():
    b_lat, b_lon = row["baignade_geom"].y, row["baignade_geom"].x
    a_lat, a_lon = row["arret_geom"].y, row["arret_geom"].x

    baignade_popup = f"""
    <b>{row['nom']}</b><br>
    Catégorie: {row['categorie']}<br>
    Surveillée: {row['baignade_surveillee']}<br>
    Adresse: {row['adresse']}<br>
    Température Moyenne: {row['avg_temp']:.1f} °C
    """
    folium.Marker(
        location=[b_lat, b_lon],
        popup=baignade_popup,
        icon=folium.Icon(color="blue", icon="tint", prefix="fa")
    ).add_to(m)

    arret_popup = f"<b>Arrêt Proche:</b> {row['arret_name']}"
    folium.Marker(
        location=[a_lat, a_lon],
        popup=arret_popup,
        icon=folium.Icon(color="green", icon="bus", prefix="fa")
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0852a55747ad9d6883d99877ef25508 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0852a55747ad9d6883d99877ef25508&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0852a55747ad9d6883d99877ef25508 = L.map(
#                 &quot;map_f0852a55747ad9d6883d99877ef25508&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc2b86e8c14a4f294c2ac1247814f8f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc2b86e8c14a4f294c2ac1247814f8f4.addTo(map_f0852a55747ad9d6883d99877ef25508);
#
#
#             var marker_387fbb9a8948c82e7fa8e7b55c1ec006 = L.marker(
#                 [43.239695, 5.362287],
#                 {
# }
#             ).addTo(map_f0852a55747ad9d6883d99877ef25508);
#
#
#             var icon_7969bc0e0a6b1c4dd743d91f3ee17dbe = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7108c019e5605aacb5297d609668b176 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2358e4ca02c20234761ea1b9d29d7ac = $(`&lt;div id=&quot;html_b2358e4ca02c20234761ea1b9d29d7ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Anse des Phoceens&lt;/b&gt;&lt;br&gt;     Catégorie: Plages&lt;br&gt;     Surveillée: False&lt;br&gt;     Adresse: None&lt;br&gt;     Température Moyenne: 11.7 °C     &lt;/div&gt;`)[0];
#                 popup_7108c019e5605aacb5297d609668b176.setContent(html_b2358e4ca02c20234761ea1b9d29d7ac);
#
#
#
#         marker_387fbb9a8948c82e7fa8e7b55c1ec006.bindPopup(popup_7108c019e5605aacb5297d609668b176)
#         ;
#
#
#
#
#                 marker_387fbb9a8948c82e7fa8e7b55c1ec006.setIcon(icon_7969bc0e0a6b1c4dd743d91f3ee17dbe);
#
#
#             var marker_c78da3dd8b9805a42620b378c7520123 = L.marker(
#                 [43.238692, 5.365196],
#                 {
# }
#             ).addTo(map_f0852a55747ad9d6883d99877ef25508);
#
#
#             var icon_dcd9a52ece7cf587b7a8df495991b947 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bus&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d4a38defc44c434865209072c9d82e38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da78e29389134cfde3a638e8d9de7b81 = $(`&lt;div id=&quot;html_da78e29389134cfde3a638e8d9de7b81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arrêt Proche:&lt;/b&gt; Engalière&lt;/div&gt;`)[0];
#                 popup_d4a38defc44c434865209072c9d82e38.setContent(html_da78e29389134cfde3a638e8d9de7b81);
#
#
#
#         marker_c78da3dd8b9805a42620b378c7520123.bindPopup(popup_d4a38defc44c434865209072c9d82e38)
#         ;
#
#
#
#
#                 marker_c78da3dd8b9805a42620b378c7520123.setIcon(icon_dcd9a52ece7cf587b7a8df495991b947);
#
#
#             var marker_ecdf312a37ac84a49e211037c0abea10 = L.marker(
#                 [43.237535, 5.360873],
#                 {
# }
#             ).addTo(map_f0852a55747ad9d6883d99877ef25508);
#
#
#             var icon_53010bcb4d25c41c73270367dbcb99be = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tint&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ee2b74da753b942e99c64c35523b0557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_281c40b6862475269528e00463750641 = $(`&lt;div id=&quot;html_281c40b6862475269528e00463750641&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Anse des Sablettes (plage du Colombet)&lt;/b&gt;&lt;br&gt;     Catégorie: Plages&lt;br&gt;     Surveillée: False&lt;br&gt;     Adresse: None&lt;br&gt;     Température Moyenne: 11.7 °C     &lt;/div&gt;`)[0];
#                 popup_ee2b74da753b942e99c64c35523b0557.setContent(html_281c40b6862475269528e00463750641);
#
#
#
#         marker_ecdf312a37ac84a49e211037c0abea10.bindPopup(popup_ee2b74da753b942e99c64c35523b0557)
#         ;
#
#
#
#
#                 marker_ecdf312a37ac84a49e211037c0abea10.

# %% [markdown]
# Lieux et dates (5 prochains jours) de Baignades suggérés selon la température

# %%
# SQL query to fetch bathing sites with ideal weather
sql = """
SELECT 
    nom_du_site,
    categorie,
    baignade_surveillee,
    adresse,
    numero_de_telephone,
    date,
    temperature,
    humidite,
    vitesse_vent,
    description_meteo,
    ST_AsText(geog_baignade) AS geog_baignade
FROM baignades_best_conditions
WHERE temperature >= 25 AND vitesse_vent <= 20
"""

# Fetch data
with engine.begin() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert WKT to Shapely geometries
df["baignade_geom"] = df["geog_baignade"].apply(wkt.loads)

# Create a Folium map centered on Marseille
map_center = [43.296482, 5.36978]
m = folium.Map(location=map_center, zoom_start=12)

# Add markers
for _, row in df.iterrows():
    lat, lon = row["baignade_geom"].y, row["baignade_geom"].x
    popup = f"""
    <b>{row['nom_du_site']}</b><br>
    {row['categorie']} - Surveillée: {row['baignade_surveillee']}<br>
    Adresse: {row['adresse']}<br>
    ☀️ {row['description_meteo']}<br>
    🌡 Temp: {row['temperature']}°C<br>
    💨 Vent: {row['vitesse_vent']} km/h<br>
    💧 Humidité: {row['humidite']}%<br>
    📅 {row['date']}
    """
    folium.Marker(
        location=[lat, lon],
        popup=popup,
        icon=folium.Icon(color="orange", icon="sun", prefix="fa")
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc7bcaebe3530ec58c2301acce52275f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc7bcaebe3530ec58c2301acce52275f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc7bcaebe3530ec58c2301acce52275f = L.map(
#                 &quot;map_bc7bcaebe3530ec58c2301acce52275f&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb18d06f8e325f9719c2996f95358168 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb18d06f8e325f9719c2996f95358168.addTo(map_bc7bcaebe3530ec58c2301acce52275f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Display Plages avec Température Moyennes

# %%
# SQL query to fetch average temperature data
sql = """
SELECT 
    nom_du_site,
    date,
    avg_temp,
    ST_AsText(geog_baignade) AS geog_baignade
FROM avg_temp_per_baignade
"""

# Fetch data
with engine.begin() as connection:
    df = pd.read_sql_query(text(sql), connection)

# Convert WKT to Shapely geometries
df["baignade_geom"] = df["geog_baignade"].apply(wkt.loads)

# Create a Folium map centered on Marseille
map_center = [43.296482, 5.36978]
m = folium.Map(location=map_center, zoom_start=12)

# Add markers for each bathing site
for _, row in df.iterrows():
    lat, lon = row["baignade_geom"].y, row["baignade_geom"].x
    popup = f"""
    <b>{row['nom_du_site']}</b><br>
    📅 {row['date']}<br>
    🌡 Avg Temp: {row['avg_temp']}°C
    """
    folium.Marker(
        location=[lat, lon],
        popup=popup,
        icon=folium.Icon(color="blue", icon="thermometer-half", prefix="fa")
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_286dbf62a3bf62a117526d1154cbff38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_286dbf62a3bf62a117526d1154cbff38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_286dbf62a3bf62a117526d1154cbff38 = L.map(
#                 &quot;map_286dbf62a3bf62a117526d1154cbff38&quot;,
#                 {
#                     center: [43.296482, 5.36978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63bb0181698c401f8279fa6fe50f8479 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63bb0181698c401f8279fa6fe50f8479.addTo(map_286dbf62a3bf62a117526d1154cbff38);
#
#
#             var marker_d48f73f539ed63c6b4f6371d05420d8f = L.marker(
#                 [43.239695, 5.362287],
#                 {
# }
#             ).addTo(map_286dbf62a3bf62a117526d1154cbff38);
#
#
#             var icon_c28a2fb0c143c46c8680ecb36862b194 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;thermometer-half&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_51739649bfd9866f07e5efa5f9162852 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5db6fd4eb61bf9a5e73b845693c94156 = $(`&lt;div id=&quot;html_5db6fd4eb61bf9a5e73b845693c94156&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Anse des Phoceens&lt;/b&gt;&lt;br&gt;     📅 2025-04-18&lt;br&gt;     🌡 Avg Temp: 11.72°C     &lt;/div&gt;`)[0];
#                 popup_51739649bfd9866f07e5efa5f9162852.setContent(html_5db6fd4eb61bf9a5e73b845693c94156);
#
#
#
#         marker_d48f73f539ed63c6b4f6371d05420d8f.bindPopup(popup_51739649bfd9866f07e5efa5f9162852)
#         ;
#
#
#
#
#                 marker_d48f73f539ed63c6b4f6371d05420d8f.setIcon(icon_c28a2fb0c143c46c8680ecb36862b194);
#
#
#             var marker_79afa8b9a5173e2fb4c4f7816d6cfed0 = L.marker(
#                 [43.237535, 5.360873],
#                 {
# }
#             ).addTo(map_286dbf62a3bf62a117526d1154cbff38);
#
#
#             var icon_7179361d9dad6fe0493681c2c14785f9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;thermometer-half&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fc1b7d62c0de61bc6bbf8981361cff78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6564a7f92aec1c368b8011efb23ff8bd = $(`&lt;div id=&quot;html_6564a7f92aec1c368b8011efb23ff8bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Anse des Sablettes (plage du Colombet)&lt;/b&gt;&lt;br&gt;     📅 2025-04-18&lt;br&gt;     🌡 Avg Temp: 11.72°C     &lt;/div&gt;`)[0];
#                 popup_fc1b7d62c0de61bc6bbf8981361cff78.setContent(html_6564a7f92aec1c368b8011efb23ff8bd);
#
#
#
#         marker_79afa8b9a5173e2fb4c4f7816d6cfed0.bindPopup(popup_fc1b7d62c0de61bc6bbf8981361cff78)
#         ;
#
#
#
#
#                 marker_79afa8b9a5173e2fb4c4f7816d6cfed0.setIcon(icon_7179361d9dad6fe0493681c2c14785f9);
#
#
#             var marker_b5aa4c55de8b874479fb65ce4f1ea66b = L.marker(
#                 [43.241082, 5.362628],
#                 {
# }
#             ).addTo(map_286dbf62a3bf62a117526d1154cbff38);
#
#
#             var icon_1db1675667e0d91e80b3cc0a5394dbca = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;thermometer-half&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8f9e9166cc363a29137bb4ae3a3df83e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b18514d249cd3fee81ea8d40ef861e4 = $(`&lt;div id=&quot;html_1b18514d249cd3fee81ea8d40ef861e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Bain des Dames&lt;/b&gt;&lt;br&gt;     📅 2025-04-18&lt;br&gt;     🌡 Avg Temp: 11.72°C     &lt;/div&gt;`)[0];
#                 popup_8f9e9166cc363a29137bb4ae3a3df83e.setContent(html_1b18514d249cd3fee81ea8d40ef861e4);
#
#
#
#         marker_b5aa4c55de8b874479fb65ce4f1ea66b.bindPopup(popup_8f9e9166cc363a29137bb4ae3a3df83e)
#         ;
#
#
#
#
#                 marker_b5aa4c55de8b874479fb65ce4f1ea66b.setIcon(icon_1db1675667e0d91e80b3cc0a5394dbca);

# %% [markdown]
# # Your Playground
# Try our views

# %%
sql = """
# Your SQL query here
"""

""" Available views with columns:
- evenements_arrets( evenement, evenement_description, evenement_lieu, debut_evenement, fin_evenement, arret_name, geog_evenement, geog_arret, distance)
- restaurant_nearest_stops(restaurant_name, specialites, periode_ouverte, note, review_count, geog_restaurant, arret_id, arret_name, geog_arret, distance, stop_rank)
- nb_evenements_par_arret( arret_name, nb_evenements)
- nb_restaurants_par_arret( arret_name, nb_restaurants)
- mini_itineraire_event_good_restaurant_arret( evenement, evenement_description, evenement_adresse, date_debut, date_fin, restaurant_name, restaurant_description, specialites, periode_ouverte, note, review_count, arret_name, arret_id, distance_event_restaurant, distance_restaurant_arret, geog_evenement, geog_restaurant, geog_arret)
- restaurant_nearest_event( evenement, evenement_description, evenement_adresse, date_debut, date_fin, restaurant_name, note, review_count, restaurant_description, specialites, periode_ouverte, geog_restaurant, distance, geog_evenement)
- baignades_nearest_stops( nom, arret_name, categorie, baignade_surveillee, adresse, numero_de_telephone, geog_baignade, geog_arret, distance)
- baignades_meteo( nom_du_site, categorie, baignade_surveillee, adresse, numero_de_telephone, forecast_time, temperature, humidite, vitesse_vent, description_meteo, geog_baignade)
- baignades_best_conditions( nom_du_site, categorie, baignade_surveillee, adresse, numero_de_telephone, date, temperature, humidite, vitesse_vent, description_meteo, geog_baignade)
- baignades_with_nearest_stop_and_temp( nom_du_site, categorie, baignade_surveillee, adresse, numero_de_telephone, date, temperature, humidite, vitesse_vent, description_meteo, geog_baignade, arret_name, arret_id, distance)
- avg_temp_per_baignade( nom_du_site, date, avg_temp, geog_baignade)

"""

# Fetch data
with engine.begin() as connection:
    df = pd.read_sql_query(text(sql), connection)


# If you want to visualize the data on a map, you can use Folium

# Convert WKT to Shapely geometries
# df["<geography column>"] = df["<geography column>"].apply(wkt.loads)

# Create a Folium map centered on Marseille

# map_center = [43.296482, 5.36978]
# m = folium.Map(location=map_center, zoom_start=12)

# Add markers

# for _, row in df.iterrows():
#     lat, lon = row["<geography column>"].y, row["<geography column>"].x
    
#     folium.Marker(
#         location=[lat, lon],
#         icon=folium.Icon(color="orange", icon="sun", prefix="fa")
#     ).add_to(m)

# m
